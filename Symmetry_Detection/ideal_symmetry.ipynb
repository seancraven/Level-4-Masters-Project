# %%
import sys
sys.path.append('/home/sean/Documents/Work/Level 4/Level-4-Masters-Project')
import numpy as np
import pandas as pd
import random

# Setup plotting with matplotlib
import seaborn as sb
import matplotlib
import matplotlib.pyplot as plt
## setup latex plotting
#plt.rc('text', usetex=True)
plt.rc('font', family='serif')
## make font size bigger
matplotlib.rcParams.update({'font.size': 16})
## but make legend smaller
matplotlib.rcParams.update({'legend.fontsize': 14})
## change line thickness
matplotlib.rcParams.update({'lines.linewidth' : 1.75})

import Hyperparam_Testing.Testing_Notebooks.chirallag as cL
import Hyperparam_Testing.Testing_Notebooks.Common_Functions as cf
from tensorflow import keras
from tensorflow.keras import layers 
from tensorflow.keras import models 
import scipy.stats as stats

# %%
N=3
gens = cL.gen_gellman(3)
F0 = 1



def matprint(mat, fmt="g"):
    col_maxes = [max([len(("{:"+fmt+"}").format(x)) for x in col]) for col in mat.T]
    for x in mat:
        for i, y in enumerate(x):
            print(("{:"+str(col_maxes[i])+fmt+"}").format(y), end="  ")
        print("")
        
liststrucSU3 = np.array([[1,2,3,1],[1,4,7,.5],[1,5,6,-.5],[2,4,6,.5],[2,5,7,.5],[3,4,5,.5],[3,6,7,-.5],[4,5,8,3**0.5/2],[6,7,8,3**0.5/2]])
liststrucSU2 = np.array([[1,2,3,1],[3,2,1,1]])

def adjointSUN(dim,liststruc):
    dimSUN=dim**2-1
#     admat = np.zeros((8,8,8))
    admat = np.zeros((dimSUN,dimSUN,dimSUN))
    for i in range(liststruc.shape[0]):
        strucc = liststruc[i]
        strucc1 = int(strucc[0])-1
        strucc2 = int(strucc[1])-1
        strucc3 = int(strucc[2])-1
        admat[strucc1,strucc2,strucc3]=strucc[3]
        admat[strucc1,strucc3,strucc2]=-strucc[3]
        admat[strucc3,strucc1,strucc2]=strucc[3]
        admat[strucc3,strucc2,strucc1]=-strucc[3]
        admat[strucc2,strucc3,strucc1]=strucc[3]
        admat[strucc2,strucc1,strucc3]=-strucc[3]
    return admat

adjointSU3 = adjointSUN(3,liststrucSU3)

# %%
# To do, make these work when not supplying stacks of epsilon and transformations.

def get_SO_trans(eps,N):
    ''' Produces 'infinitesimal' transformation matrices for SO(N) given epsilon.
        Epsilon is size of transformation and should be a numpy array of dimension 1.
        N must be larger than 1.
    '''
    
    trans_number = len(eps) 
    # Generate rotation matrices
    SO_samp = np.zeros((trans_number,N,N))

    # Set random off diagonal element of each matrix to one (surely must be a better way to do this)
    poss_inds = range(N)
    SO_inds = [random.sample(poss_inds,2) for i in range(trans_number)]
    SO_indsflat = [i*(N)**2+x*(N)+y for i,(x,y) in enumerate(SO_inds)]
    SO_samp.flat[SO_indsflat] += 1

    # Is this transpose faster than repeating assignment above?
    SO_samp = SO_samp - np.transpose(SO_samp,axes=[0,2,1])
    SO_trans = np.identity(N) + eps[:,None,None]*SO_samp
    # Normalise so that det = 1
    #norm = np.power(np.linalg.det(SO_trans),-1/(N))
    #SO_trans = norm[:,None,None]*SO_trans
    return SO_trans
  
def get_SU_trans(eps,N,liststruct):
    ''' Produces 'infinitesimal' transformation matrices for SO(N) given epsilon.
        Epsilon is size of transformation and should be a numpy array of dimension 1.
        N must be larger than 1.
        Calls adjointSUN which requires liststruct
    '''
    adjointSU = adjointSUN(N,liststruct)
    
    genno=np.random.randint(0,N*N-2,number_predictions)
    SU_trans = np.identity(N*N-1)+eps[:,None,None]*adjointSU[genno]
    # Normalise so that det = 1
    #norm = np.power(np.linalg.det(SU_trans),-1/(N*N-1))
    #SU_trans = norm[:,None,None]*SU_trans
    return SU_trans
    
def apply_trans(trans,vec):
    ''' Apply transformation trans to vector. Assumes both trans and vec are stacks.'''
    trans_vec=np.matmul(trans,vec[:,:,None]).squeeze()
    return trans_vec

# %%
# Compare Transformations
epsmax = 100
epsmin = 0.001
eps_intervals=200
number_predictions=100000


pi=np.random.rand(number_predictions,N*N-1)
dpi=np.random.rand(number_predictions,N*N-1)

# Get epsilons, create copies
eps_vals=np.logspace(np.log10(epsmin),np.log10(epsmax),num=eps_intervals)
eps = np.zeros(number_predictions)
for i,val in enumerate(eps_vals): 
    eps[i*int(number_predictions/eps_intervals):(i+1)*int(number_predictions/eps_intervals)] = val
# Set leftovers to max value
eps[(i+1)*int(number_predictions/eps_intervals):]=val

# SO(N) transformations
SO_trans = get_SO_trans(eps,N*N-1)

SO_pi = apply_trans(SO_trans,pi)
SO_dpi = apply_trans(SO_trans,dpi)

# SU(N) transformations

SU_trans = get_SU_trans(eps,N,liststrucSU3)

SU_pi = apply_trans(SU_trans,pi)
SU_dpi = apply_trans(SU_trans,dpi)


# Get potential values, only care about real part (non zero imag should just be numerical precision errors)

orig_V = cL.get_V(pi,dpi,gens,F0).real
SO_V = cL.get_V(SO_pi,SO_dpi,gens,F0).real
SU_V = cL.get_V(SU_pi,SU_dpi,gens,F0).real

SO_Vdiff = (SO_V - orig_V)/orig_V
SU_Vdiff = (SU_V - orig_V)/orig_V

rand_means = np.mean(np.hstack([np.abs(pi) , np.abs(dpi)]),axis=-1)

# %%
print("Average error of SU(3) transformation: ",np.mean(np.abs(SU_Vdiff)),
      ", and of rotation: ",np.mean(np.abs(SO_Vdiff)))

print("Average potential value: ",np.mean(np.abs(orig_V)),", average pion value:",np.mean(rand_means))
# Out:
# Average error of SU(3) transformation:  377613.3672339693 , and of rotation:  105274.91918940836
# Average potential value:  0.19466136305174722 , average pion value: 0.5001787043734557

# %%
# Standard error by hand to compare with seaborn lineplot

fig,ax = plt.subplots(1,figsize=(9,6))

# Evaluate std deviation is epsilon is created using interval
SO_Vdiff_eps = [np.abs(SO_Vdiff[np.where(eps==val)]) for val in eps_vals]
mean_SO = np.mean(SO_Vdiff_eps,axis=-1)
std_dev_SO = np.std(SO_Vdiff_eps,axis=-1)
std_error_SO = std_dev_SO/np.sqrt([len(s) for s in SO_Vdiff_eps])
SU_Vdiff_eps = [np.abs(SU_Vdiff[np.where(eps==val)]) for val in eps_vals]
mean_SU = np.mean(SU_Vdiff_eps,axis=-1)
std_dev_SU = np.std(SU_Vdiff_eps,axis=-1)
std_error_SU = std_dev_SU/np.sqrt([len(s) for s in SU_Vdiff_eps])
#print(std_dev_SU)

#print(std_error_SU)
ax.plot(eps_vals,mean_SO,marker='.',label='SO({:})'.format(N*N-1))
ax.plot(eps_vals,mean_SU,marker='.',label='SU({:})'.format(N))
Range = 1
ax.fill_between(eps_vals,mean_SO-Range*std_error_SO, mean_SO+Range*std_error_SO,color='blue',alpha=0.5)
ax.fill_between(eps_vals,mean_SU-Range*std_error_SU, mean_SU+Range*std_error_SU,color='orange',alpha=0.5)

ax.set_xlabel(r'$\epsilon$')
ax.set_ylabel(r'$\Delta V$')
ax.set_xscale('log')
ax.set_yscale('log')
ax.legend()
ax.set_ylim(1e-7,1)
ax.set_xlim(1e-3,1)

#fig.tight_layout()
#fig.savefig('DeltaV.png',dpi=200)
# Out:
# (0.001, 1)

# %%
###Find offsets so fit lines line up
so_grad, so_intercept,_,_,_ = stats.linregress(eps_vals,abs(mean_SO))
su_intercept = 10**stats.linregress(np.log10(eps_vals),np.log10(abs(mean_SU)))[0]

# %%
fig,ax = plt.subplots(1,figsize=(9,6))


data = pd.DataFrame({'epsilon':eps,'SOdiff':np.abs(SO_Vdiff),'SUdiff':np.abs(SU_Vdiff)})
sb.lineplot(data=data,x='epsilon',y='SOdiff',label='SO({:})'.format(N*N-1),ci=99,color = 'black' )
sb.lineplot(data=data,x='epsilon',y='SUdiff',label='SU({:})'.format(N),ci=99, color = 'Red')



x = np.logspace(-3,1,100)
y1 = np.exp(x)-(1+x)
y = 1/(1-x)-(1)
#ax.plot(x,y,color="green")
ax.plot(x,x,color="Black",linestyle='--')
ax.grid(False)
#ax.plot(x,y1,color="orange")
ax.plot(x,(x**2),color="Red",linestyle='--',linewidth = 1)


ax.set_xlabel(r'$\epsilon$')
ax.set_ylabel(r'$\Delta V$')
ax.set_xscale('log')
ax.set_yscale('log')
ax.grid(False)
ax.legend()
ax.set_ylim(1e-7,10)
ax.set_xlim(1e-3,10)
fig.tight_layout()
fig.savefig('DeltaV.jpeg',dpi=200,transparent=False)

# %%
data.to_csv('../Training_Data/symetric_training_data_epsilon_and_vdiff.csv')

# %%
[[train_x,train_y],[val_x,val_y]]= cf.gen_and_load(10**5,10**3)

# %%
inital_model = models.Sequential()
inital_model.add(layers.Input(train_x.shape[1]))
inital_model.add(layers.Dense(60,activation='relu'))
inital_model.add(layers.Dense(60,activation='relu'))
inital_model.add(layers.Dense(1))
inital_model.compile(optimizer = 'Adam',loss = 'mape', metrics = [['mean_absolute_error'],['mean_absolute_percentage_error']])
inital_model.summary()

epochs = 50
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense (Dense)                (None, 60)                1020
# _________________________________________________________________
# dense_1 (Dense)              (None, 60)                3660
# _________________________________________________________________
# dense_2 (Dense)              (None, 1)                 61
# =================================================================
# Total params: 4,741
# Trainable params: 4,741
# Non-trainable params: 0
# _________________________________________________________________
# 2022-02-08 14:59:49.435645: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-02-08 14:59:49.440286: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-02-08 14:59:49.440591: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-02-08 14:59:49.441051: I tensorflow/core/platform/cpu_feature_guard.cc:142] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2022-02-08 14:59:49.441721: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-02-08 14:59:49.441925: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-02-08 14:59:49.442112: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-02-08 14:59:49.694534: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-02-08 14:59:49.694764: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-02-08 14:59:49.694958: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-02-08 14:59:49.695132: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1510] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 2286 MB memory:  -> device: 0, name: NVIDIA GeForce GTX 970, pci bus id: 0000:2b:00.0, compute capability: 5.2

# %%
history = inital_model.fit(train_x,train_y,validation_data = (val_x,val_y),batch_size= 256, epochs =epochs)
# Out:
# 2022-02-08 14:59:49.795755: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:185] None of the MLIR Optimization Passes are enabled (registered 2)
# Epoch 1/50
# 387/387 [==============================] - 1s 1ms/step - loss: 60.4946 - mean_absolute_error: 0.0762 - mean_absolute_percentage_error: 60.4946 - val_loss: 50.2435 - val_mean_absolute_error: 0.0711 - val_mean_absolute_percentage_error: 50.2435
# Epoch 2/50
# 387/387 [==============================] - 0s 930us/step - loss: 36.9136 - mean_absolute_error: 0.0484 - mean_absolute_percentage_error: 36.9136 - val_loss: 36.5722 - val_mean_absolute_error: 0.0452 - val_mean_absolute_percentage_error: 36.5722
# Epoch 3/50
# 387/387 [==============================] - 0s 1ms/step - loss: 24.4485 - mean_absolute_error: 0.0304 - mean_absolute_percentage_error: 24.4485 - val_loss: 25.3907 - val_mean_absolute_error: 0.0233 - val_mean_absolute_percentage_error: 25.3907
# Epoch 4/50
# 387/387 [==============================] - 0s 1ms/step - loss: 20.5885 - mean_absolute_error: 0.0244 - mean_absolute_percentage_error: 20.5885 - val_loss: 17.4574 - val_mean_absolute_error: 0.0192 - val_mean_absolute_percentage_error: 17.4574
# Epoch 5/50
# 387/387 [==============================] - 0s 1ms/step - loss: 17.8993 - mean_absolute_error: 0.0215 - mean_absolute_percentage_error: 17.8993 - val_loss: 23.3638 - val_mean_absolute_error: 0.0218 - val_mean_absolute_percentage_error: 23.3638
# Epoch 6/50
# 387/387 [==============================] - 0s 1ms/step - loss: 17.1714 - mean_absolute_error: 0.0205 - mean_absolute_percentage_error: 17.1714 - val_loss: 15.6610 - val_mean_absolute_error: 0.0188 - val_mean_absolute_percentage_error: 15.6610
# Epoch 7/50
# 387/387 [==============================] - 0s 1ms/step - loss: 16.3299 - mean_absolute_error: 0.0195 - mean_absolute_percentage_error: 16.3299 - val_loss: 14.1097 - val_mean_absolute_error: 0.0164 - val_mean_absolute_percentage_error: 14.1097
# Epoch 8/50
# 387/387 [==============================] - 0s 1ms/step - loss: 16.1345 - mean_absolute_error: 0.0192 - mean_absolute_percentage_error: 16.1345 - val_loss: 15.3295 - val_mean_absolute_error: 0.0177 - val_mean_absolute_percentage_error: 15.3295
# Epoch 9/50
# 387/387 [==============================] - 0s 1ms/step - loss: 15.0927 - mean_absolute_error: 0.0183 - mean_absolute_percentage_error: 15.0927 - val_loss: 13.2518 - val_mean_absolute_error: 0.0161 - val_mean_absolute_percentage_error: 13.2518
# Epoch 10/50
# 387/387 [==============================] - 0s 1ms/step - loss: 15.3608 - mean_absolute_error: 0.0183 - mean_absolute_percentage_error: 15.3608 - val_loss: 14.0612 - val_mean_absolute_error: 0.0164 - val_mean_absolute_percentage_error: 14.0612
# Epoch 11/50
# 387/387 [==============================] - 0s 1ms/step - loss: 14.8508 - mean_absolute_error: 0.0178 - mean_absolute_percentage_error: 14.8508 - val_loss: 14.1115 - val_mean_absolute_error: 0.0159 - val_mean_absolute_percentage_error: 14.1115
# Epoch 12/50
# 387/387 [==============================] - 0s 955us/step - loss: 15.1633 - mean_absolute_error: 0.0180 - mean_absolute_percentage_error: 15.1633 - val_loss: 13.2005 - val_mean_absolute_error: 0.0155 - val_mean_absolute_percentage_error: 13.2005
# Epoch 13/50
# 387/387 [==============================] - 0s 979us/step - loss: 14.4064 - mean_absolute_error: 0.0173 - mean_absolute_percentage_error: 14.4064 - val_loss: 13.9911 - val_mean_absolute_error: 0.0153 - val_mean_absolute_percentage_error: 13.9911
# Epoch 14/50
# 387/387 [==============================] - 0s 1ms/step - loss: 14.5833 - mean_absolute_error: 0.0174 - mean_absolute_percentage_error: 14.5833 - val_loss: 14.3848 - val_mean_absolute_error: 0.0167 - val_mean_absolute_percentage_error: 14.3848
# Epoch 15/50
# 387/387 [==============================] - 0s 1ms/step - loss: 13.6198 - mean_absolute_error: 0.0166 - mean_absolute_percentage_error: 13.6198 - val_loss: 12.4964 - val_mean_absolute_error: 0.0152 - val_mean_absolute_percentage_error: 12.4964
# Epoch 16/50
# 387/387 [==============================] - 0s 980us/step - loss: 13.8118 - mean_absolute_error: 0.0166 - mean_absolute_percentage_error: 13.8118 - val_loss: 13.1033 - val_mean_absolute_error: 0.0154 - val_mean_absolute_percentage_error: 13.1033
# Epoch 17/50
# 387/387 [==============================] - 0s 990us/step - loss: 13.3893 - mean_absolute_error: 0.0162 - mean_absolute_percentage_error: 13.3893 - val_loss: 12.1021 - val_mean_absolute_error: 0.0141 - val_mean_absolute_percentage_error: 12.1021
# Epoch 18/50
# 387/387 [==============================] - 0s 1ms/step - loss: 13.3122 - mean_absolute_error: 0.0161 - mean_absolute_percentage_error: 13.3122 - val_loss: 12.0189 - val_mean_absolute_error: 0.0140 - val_mean_absolute_percentage_error: 12.0189
# Epoch 19/50
# 387/387 [==============================] - 0s 1ms/step - loss: 13.3315 - mean_absolute_error: 0.0160 - mean_absolute_percentage_error: 13.3315 - val_loss: 12.4837 - val_mean_absolute_error: 0.0147 - val_mean_absolute_percentage_error: 12.4837
# Epoch 20/50
# 387/387 [==============================] - 0s 1ms/step - loss: 13.0241 - mean_absolute_error: 0.0156 - mean_absolute_percentage_error: 13.0241 - val_loss: 13.3571 - val_mean_absolute_error: 0.0155 - val_mean_absolute_percentage_error: 13.3571
# Epoch 21/50
# 387/387 [==============================] - 0s 1ms/step - loss: 12.3659 - mean_absolute_error: 0.0149 - mean_absolute_percentage_error: 12.3659 - val_loss: 11.3012 - val_mean_absolute_error: 0.0135 - val_mean_absolute_percentage_error: 11.3012
# Epoch 22/50
# 387/387 [==============================] - 0s 935us/step - loss: 12.3481 - mean_absolute_error: 0.0149 - mean_absolute_percentage_error: 12.3481 - val_loss: 12.4134 - val_mean_absolute_error: 0.0138 - val_mean_absolute_percentage_error: 12.4134
# Epoch 23/50
# 387/387 [==============================] - 0s 956us/step - loss: 12.1833 - mean_absolute_error: 0.0147 - mean_absolute_percentage_error: 12.1833 - val_loss: 10.8349 - val_mean_absolute_error: 0.0131 - val_mean_absolute_percentage_error: 10.8349
# Epoch 24/50
# 387/387 [==============================] - 0s 1ms/step - loss: 11.7012 - mean_absolute_error: 0.0142 - mean_absolute_percentage_error: 11.7012 - val_loss: 10.8193 - val_mean_absolute_error: 0.0125 - val_mean_absolute_percentage_error: 10.8193
# Epoch 25/50
# 387/387 [==============================] - 0s 1ms/step - loss: 11.6229 - mean_absolute_error: 0.0141 - mean_absolute_percentage_error: 11.6229 - val_loss: 10.4013 - val_mean_absolute_error: 0.0130 - val_mean_absolute_percentage_error: 10.4013
# Epoch 26/50
# 387/387 [==============================] - 0s 1ms/step - loss: 11.4942 - mean_absolute_error: 0.0139 - mean_absolute_percentage_error: 11.4942 - val_loss: 11.9288 - val_mean_absolute_error: 0.0136 - val_mean_absolute_percentage_error: 11.9288
# Epoch 27/50
# 387/387 [==============================] - 0s 1ms/step - loss: 11.5152 - mean_absolute_error: 0.0139 - mean_absolute_percentage_error: 11.5152 - val_loss: 10.8392 - val_mean_absolute_error: 0.0127 - val_mean_absolute_percentage_error: 10.8392
# Epoch 28/50
# 387/387 [==============================] - 0s 1ms/step - loss: 11.4835 - mean_absolute_error: 0.0138 - mean_absolute_percentage_error: 11.4835 - val_loss: 11.5174 - val_mean_absolute_error: 0.0130 - val_mean_absolute_percentage_error: 11.5174
# Epoch 29/50
# 387/387 [==============================] - 0s 1ms/step - loss: 11.0533 - mean_absolute_error: 0.0134 - mean_absolute_percentage_error: 11.0533 - val_loss: 12.4602 - val_mean_absolute_error: 0.0147 - val_mean_absolute_percentage_error: 12.4602
# Epoch 30/50
# 387/387 [==============================] - 0s 1ms/step - loss: 10.9136 - mean_absolute_error: 0.0131 - mean_absolute_percentage_error: 10.9136 - val_loss: 9.8627 - val_mean_absolute_error: 0.0115 - val_mean_absolute_percentage_error: 9.8627
# Epoch 31/50
# 387/387 [==============================] - 0s 1ms/step - loss: 10.8592 - mean_absolute_error: 0.0131 - mean_absolute_percentage_error: 10.8592 - val_loss: 10.4171 - val_mean_absolute_error: 0.0120 - val_mean_absolute_percentage_error: 10.4171
# Epoch 32/50
# 387/387 [==============================] - 0s 1ms/step - loss: 10.5069 - mean_absolute_error: 0.0127 - mean_absolute_percentage_error: 10.5069 - val_loss: 9.7344 - val_mean_absolute_error: 0.0112 - val_mean_absolute_percentage_error: 9.7344
# Epoch 33/50
# 387/387 [==============================] - 0s 915us/step - loss: 10.4842 - mean_absolute_error: 0.0126 - mean_absolute_percentage_error: 10.4842 - val_loss: 13.7710 - val_mean_absolute_error: 0.0132 - val_mean_absolute_percentage_error: 13.7710
# Epoch 34/50
# 387/387 [==============================] - 0s 943us/step - loss: 10.6074 - mean_absolute_error: 0.0126 - mean_absolute_percentage_error: 10.6074 - val_loss: 11.3005 - val_mean_absolute_error: 0.0118 - val_mean_absolute_percentage_error: 11.3005
# Epoch 35/50
# 387/387 [==============================] - 0s 969us/step - loss: 9.9647 - mean_absolute_error: 0.0121 - mean_absolute_percentage_error: 9.9647 - val_loss: 9.5207 - val_mean_absolute_error: 0.0107 - val_mean_absolute_percentage_error: 9.5207
# Epoch 36/50
# 387/387 [==============================] - 0s 1ms/step - loss: 10.3008 - mean_absolute_error: 0.0123 - mean_absolute_percentage_error: 10.3008 - val_loss: 9.8710 - val_mean_absolute_error: 0.0112 - val_mean_absolute_percentage_error: 9.8710
# Epoch 37/50
# 387/387 [==============================] - 0s 1ms/step - loss: 9.7723 - mean_absolute_error: 0.0118 - mean_absolute_percentage_error: 9.7723 - val_loss: 9.1566 - val_mean_absolute_error: 0.0109 - val_mean_absolute_percentage_error: 9.1566
# Epoch 38/50
# 387/387 [==============================] - 0s 1ms/step - loss: 10.2917 - mean_absolute_error: 0.0122 - mean_absolute_percentage_error: 10.2917 - val_loss: 9.8905 - val_mean_absolute_error: 0.0117 - val_mean_absolute_percentage_error: 9.8905
# Epoch 39/50
# 387/387 [==============================] - 0s 958us/step - loss: 9.5974 - mean_absolute_error: 0.0116 - mean_absolute_percentage_error: 9.5974 - val_loss: 9.1662 - val_mean_absolute_error: 0.0102 - val_mean_absolute_percentage_error: 9.1662
# Epoch 40/50
# 387/387 [==============================] - 0s 956us/step - loss: 9.5801 - mean_absolute_error: 0.0116 - mean_absolute_percentage_error: 9.5801 - val_loss: 10.5635 - val_mean_absolute_error: 0.0120 - val_mean_absolute_percentage_error: 10.5635
# Epoch 41/50
# 387/387 [==============================] - 0s 951us/step - loss: 9.6591 - mean_absolute_error: 0.0116 - mean_absolute_percentage_error: 9.6591 - val_loss: 10.0499 - val_mean_absolute_error: 0.0115 - val_mean_absolute_percentage_error: 10.0499
# Epoch 42/50
# 387/387 [==============================] - 0s 954us/step - loss: 9.2527 - mean_absolute_error: 0.0112 - mean_absolute_percentage_error: 9.2527 - val_loss: 10.2356 - val_mean_absolute_error: 0.0114 - val_mean_absolute_percentage_error: 10.2356
# Epoch 43/50
# 387/387 [==============================] - 0s 980us/step - loss: 9.3261 - mean_absolute_error: 0.0113 - mean_absolute_percentage_error: 9.3261 - val_loss: 8.7517 - val_mean_absolute_error: 0.0098 - val_mean_absolute_percentage_error: 8.7517
# Epoch 44/50
# 387/387 [==============================] - 0s 1ms/step - loss: 9.3262 - mean_absolute_error: 0.0112 - mean_absolute_percentage_error: 9.3262 - val_loss: 9.4619 - val_mean_absolute_error: 0.0106 - val_mean_absolute_percentage_error: 9.4619
# Epoch 45/50
# 387/387 [==============================] - 0s 980us/step - loss: 9.1777 - mean_absolute_error: 0.0110 - mean_absolute_percentage_error: 9.1777 - val_loss: 10.8850 - val_mean_absolute_error: 0.0118 - val_mean_absolute_percentage_error: 10.8850
# Epoch 46/50
# 387/387 [==============================] - 0s 1ms/step - loss: 9.2567 - mean_absolute_error: 0.0111 - mean_absolute_percentage_error: 9.2567 - val_loss: 9.6167 - val_mean_absolute_error: 0.0105 - val_mean_absolute_percentage_error: 9.6167
# Epoch 47/50
# 387/387 [==============================] - 0s 1ms/step - loss: 8.7759 - mean_absolute_error: 0.0107 - mean_absolute_percentage_error: 8.7759 - val_loss: 8.5615 - val_mean_absolute_error: 0.0096 - val_mean_absolute_percentage_error: 8.5615
# Epoch 48/50
# 387/387 [==============================] - 0s 970us/step - loss: 8.8869 - mean_absolute_error: 0.0107 - mean_absolute_percentage_error: 8.8869 - val_loss: 11.1110 - val_mean_absolute_error: 0.0123 - val_mean_absolute_percentage_error: 11.1110
# Epoch 49/50
# 387/387 [==============================] - 0s 994us/step - loss: 8.9370 - mean_absolute_error: 0.0107 - mean_absolute_percentage_error: 8.9370 - val_loss: 8.9541 - val_mean_absolute_error: 0.0102 - val_mean_absolute_percentage_error: 8.9541
# Epoch 50/50
# 387/387 [==============================] - 0s 1ms/step - loss: 8.7679 - mean_absolute_error: 0.0106 - mean_absolute_percentage_error: 8.7679 - val_loss: 8.7463 - val_mean_absolute_error: 0.0104 - val_mean_absolute_percentage_error: 8.7463

# %%
validation_MAPE = history.history['val_mean_absolute_percentage_error']

# %%
test_data= cf.gen_and_load(10**5,0)

# %%
### Generate New test data for nn prediction
pi_dpi,v = test_data[1]
pis =pi_dpi[:,:8]
dpis = pi_dpi[:,8:]

SU_dpi_nn = apply_trans(SU_trans,dpis)
SU_pi_nn = apply_trans(SU_trans,pis)
SU_pi_dpi_nn = np.hstack((SU_pi_nn,SU_dpi_nn))
SU_V_nn_test = cL.get_V(SU_pi_nn,SU_dpi_nn,gens,F0).real
###I only want the transformed data on the interval 0-1

# %%
print('Range of Pi\' fields',np.min(SU_pi_dpi_nn),'to',np.max(SU_pi_dpi_nn))
print('Mean Pi\' Field', np.mean(SU_pi_dpi_nn))
print('Range of Pi fields',np.min(pi_dpi),'to',np.max(pi_dpi))
# Out:
# Range of Pi' fields -135.0487020282418 to 133.82145740188463
# Mean Pi' Field 0.799148681349189
# Range of Pi fields 0.023720990196245264 to 0.9999999728466511

# %%
fig , ax = plt.subplots(2,8,sharey= True, figsize = (10,8))
plt.subplots_adjust(hspace= 0.4,wspace= 0.5)
for i in range(8):
    ax[0,i].hist(SU_pi_dpi_nn[:,i], density = True, color = 'black') 
    #ax[0,i].set_xticks([0,1])
    #ax[1,i].set_xticks([0,1])
    ax[1,i].hist(SU_pi_dpi_nn[:,8+i],density = True, color = 'black')
    ax[0,i].set_xlabel('$\phi_{{{}}}$'.format(i))
    ax[1,i].set_xlabel('$d\phi_{{{}}}$'.format(i))
fig.supylabel('Frequency Density')
fig_2 = plt.figure(figsize= (10,8))
plt.hist(abs(SU_V_nn_test),density= True, bins = 1000, color = 'black',label=  '$\phi \sim U^{1/4}$')
#plt.hist(df_SU_pi_dpi_nn[:,-1],density= True, bins = 1000, color = 'blue',label=  '$\phi \sim U^{1/4}$' )
plt.xlabel('$V(\phi)$')
plt.ylabel('Frequency Density')
plt.xlim(0,10**5)
plt.legend()

# %%
cf.field_plotter(pi_dpi,v)

# %%
#Use Neural network to predict transformation
#Delta Vnn calculated for plotting 
V_nn = inital_model.predict(SU_pi_dpi_nn)
delta_V_nn = (V_nn[:,0]-v)/v

# %%
fig,ax = plt.subplots(1,figsize=(9,6))


data = pd.DataFrame({'epsilon':eps,'SOdiff':np.abs(SO_Vdiff),'SUdiff':np.abs(SU_Vdiff),'SUdiff_nn':np.abs(delta_V_nn)})
sb.lineplot(data=data,x='epsilon',y='SOdiff',label='SO({:})'.format(N*N-1),ci=95,color = 'black' )
sb.lineplot(data=data,x='epsilon',y='SUdiff',label='SU({:})'.format(N),ci=95, color = 'Red')
sb.lineplot(data=data,x='epsilon',y='SUdiff_nn',label='SU({}'.format(N)+'$)_{nn}$',ci=95, color = 'Purple')


x = np.logspace(-3,1,100)
y1 = np.exp(x)-(1+x)
y = 1/(1-x)-(1)
#ax.plot(x,y,color="green")
ax.plot(x,x*0.4,color="Black",linestyle='--')
ax.grid(False)
#ax.plot(x,y1,color="orange")
ax.plot(x,(x**2)*0.7,color="Red",linestyle='--',linewidth = 1)
ax.plot(x,np.ones_like(x)*validation_MAPE[-2]/100, color = 'purple',linestyle = '--', label = 'Network MAPE')

ax.set_xlabel(r'$\epsilon$')
ax.set_ylabel(r'$\Delta V$')
ax.set_xscale('log')
ax.set_yscale('log')
ax.grid(False)
ax.legend()
ax.set_ylim(1e-3,10)
ax.set_xlim(1e-3,10)
fig.tight_layout()
fig.savefig('DeltaV_inital.jpeg',dpi=200,transparent=False)

# %%
model = keras.models.load_model('/home/sean/Documents/Work/Level 4/Level-4-Masters-Project/Hyperparam_Testing/Testing_Notebooks/Optimised_Network/Saved_Optimised_Networks/106datapoints.h5')
# Out:
# WARNING:tensorflow:Error in loading the saved optimizer state. As a result, your model is starting with a freshly initialized optimizer.

# %%
pred_V = model.predict(pi_dpi)[:,0]
MAPE = np.mean((pred_V - v)/v)
print('MAPE = ',round(MAPE*100,2))
# Out:
# MAPE =  1.05

# %%
V_nn = model.predict(SU_pi_dpi_nn)
print(V_nn)
print(V_nn[:,0].shape)
delta_V_nn = (V_nn[:,0]-v)/v
# Out:
# [[7.7965654e-02]
#  [2.6576737e-02]
#  [8.4336847e-02]
#  ...
#  [9.1147263e+01]
#  [1.5749318e+02]
#  [1.8486609e+02]]
# (100000,)

# %%
fig_2,ax = plt.subplots(1,figsize=(9,6))
data = pd.DataFrame({'epsilon':eps,'SOdiff':np.abs(SO_Vdiff),'SUdiff':np.abs(SU_Vdiff),'SUdiff_nn':np.abs(delta_V_nn)})
sb.lineplot(data=data,x='epsilon',y='SOdiff',label='SO({:})'.format(N*N-1),ci=99,color = 'black' )
sb.lineplot(data=data,x='epsilon',y='SUdiff',label='SU({:})'.format(N),ci=99, color = 'Red')
sb.lineplot(data=data,x='epsilon',y='SUdiff_nn',label='SU({}'.format(N)+'$)_{nn}$',ci=99, color = 'Purple')


x = np.logspace(-3,1,100)
y1 = np.exp(x)-(1+x)
y = 1/(1-x)-(1)
#ax.plot(x,y,color="green")
ax.plot(x,x*0.4,color="Black",linestyle='--')
ax.grid(False)
#ax.plot(x,y1,color="orange")
ax.plot(x,(x**2)*0.7,color="Red",linestyle='--',linewidth = 1)
ax.plot(x,np.ones_like(x)*MAPE, color = 'purple',linestyle = '--', label = 'Network MAPE')

ax.set_xlabel(r'$\epsilon$')
ax.set_ylabel(r'$\Delta V$')
ax.set_xscale('log')
ax.set_yscale('log')
ax.grid(False)
ax.legend()
ax.set_ylim(1e-3,10)
ax.set_xlim(1e-3,10)
fig_2.tight_layout()
fig_2.savefig('DeltaV_improved.jpeg',dpi=200,transparent=False)
