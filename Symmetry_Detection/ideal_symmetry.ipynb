# %%
import sys
sys.path.append('/home/sean/Documents/Work/Level 4/Level-4-Masters-Project')
import numpy as np
import pandas as pd
import random
import datetime
# Setup plotting with matplotlib
import seaborn as sb
import matplotlib
import matplotlib.pyplot as plt
## setup latex plotting
plt.rc('text', usetex=True)

## make font size bigger
matplotlib.rcParams.update({'font.size': 16})
## but make legend smaller
matplotlib.rcParams.update({'legend.fontsize': 16})
## change line thickness
matplotlib.rcParams.update({'lines.linewidth' : 1.75})

matplotlib.rcParams.update({'text.latex.preamble': r'\usepackage{times}'})
matplotlib.rcParams.update({'text.latex.preamble': r'\usepackage{amsmath}'})
#matplotlib.rcParams['text.latex.preamble'] = [r'\boldmath']

import Hyperparam_Testing.Testing_Notebooks.chirallag as cL
import Hyperparam_Testing.Testing_Notebooks.Common_Functions as cf
from tensorflow import keras
from tensorflow.keras import layers 
from tensorflow.keras import models 
import scipy.stats as stats
from numpy.lib.stride_tricks import sliding_window_view
from scipy.optimize import curve_fit as fit
import os
os.environ['CUDA_VISIBLE_DEVICES'] = '-1'

# %%
N=3
gens = cL.gen_gellman(3)
F0 = 1



def matprint(mat, fmt="g"):
    col_maxes = [max([len(("{:"+fmt+"}").format(x)) for x in col]) for col in mat.T]
    for x in mat:
        for i, y in enumerate(x):
            print(("{:"+str(col_maxes[i])+fmt+"}").format(y), end="  ")
        print("")
        
liststrucSU3 = np.array([[1,2,3,1],[1,4,7,.5],[1,5,6,-.5],[2,4,6,.5],[2,5,7,.5],[3,4,5,.5],[3,6,7,-.5],[4,5,8,3**0.5/2],[6,7,8,3**0.5/2]])
liststrucSU2 = np.array([[1,2,3,1],[3,2,1,1]])

def adjointSUN(dim,liststruc):
    dimSUN=dim**2-1
#     admat = np.zeros((8,8,8))
    admat = np.zeros((dimSUN,dimSUN,dimSUN))
    for i in range(liststruc.shape[0]):
        strucc = liststruc[i]
        strucc1 = int(strucc[0])-1
        strucc2 = int(strucc[1])-1
        strucc3 = int(strucc[2])-1
        admat[strucc1,strucc2,strucc3]=strucc[3]
        admat[strucc1,strucc3,strucc2]=-strucc[3]
        admat[strucc3,strucc1,strucc2]=strucc[3]
        admat[strucc3,strucc2,strucc1]=-strucc[3]
        admat[strucc2,strucc3,strucc1]=strucc[3]
        admat[strucc2,strucc1,strucc3]=-strucc[3]
    return admat

adjointSU3 = adjointSUN(3,liststrucSU3)

# %%
# To do, make these work when not supplying stacks of epsilon and transformations.

def get_SO_trans(eps,N):
    ''' Produces 'infinitesimal' transformation matrices for SO(N) given epsilon.
        Epsilon is size of transformation and should be a numpy array of dimension 1.
        N must be larger than 1.
    '''
    
    trans_number = len(eps) 
    # Generate rotation matrices
    SO_samp = np.zeros((trans_number,N,N))

    # Set random off diagonal element of each matrix to one (surely must be a better way to do this)
    poss_inds = range(N)
    SO_inds = [random.sample(poss_inds,2) for i in range(trans_number)]
    SO_indsflat = [i*(N)**2+x*(N)+y for i,(x,y) in enumerate(SO_inds)]
    SO_samp.flat[SO_indsflat] += 1

    # Is this transpose faster than repeating assignment above?
    SO_samp = SO_samp - np.transpose(SO_samp,axes=[0,2,1])
    SO_trans = np.identity(N) + eps[:,None,None]*SO_samp
    # Normalise so that det = 1
    #norm = np.power(np.linalg.det(SO_trans),-1/(N))
    #SO_trans = norm[:,None,None]*SO_trans
    return SO_trans
  
def get_SU_trans(eps,N,liststruct):
    ''' Produces 'infinitesimal' transformation matrices for SO(N) given epsilon.
        Epsilon is size of transformation and should be a numpy array of dimension 1.
        N must be larger than 1.
        Calls adjointSUN which requires liststruct
    '''
    adjointSU = adjointSUN(N,liststruct)
    
    genno=np.random.randint(0,N*N-2,number_predictions)
    SU_trans = np.identity(N*N-1)+eps[:,None,None]*adjointSU[genno]
    # Normalise so that det = 1
    #norm = np.power(np.linalg.det(SU_trans),-1/(N*N-1))
    #SU_trans = norm[:,None,None]*SU_trans
    return SU_trans
    
def apply_trans(trans,vec):
    ''' Apply transformation trans to vector. Assumes both trans and vec are stacks.'''
    trans_vec=np.matmul(trans,vec[:,:,None]).squeeze()
    return trans_vec

# %%
# Compare Transformations
epsmax = 100
epsmin = 0.001
eps_intervals=500
number_predictions=1000000


pi=np.random.rand(number_predictions,N*N-1)
dpi=np.random.rand(number_predictions,N*N-1)

# Get epsilons, create copies
eps_vals=np.logspace(np.log10(epsmin),np.log10(epsmax),num=eps_intervals)
eps = np.zeros(number_predictions)
for i,val in enumerate(eps_vals): 
    eps[i*int(number_predictions/eps_intervals):(i+1)*int(number_predictions/eps_intervals)] = val
# Set leftovers to max value
eps[(i+1)*int(number_predictions/eps_intervals):]=val

# SO(N) transformations
SO_trans = get_SO_trans(eps,N*N-1)

SO_pi = apply_trans(SO_trans,pi)
SO_dpi = apply_trans(SO_trans,dpi)

# SU(N) transformations

SU_trans = get_SU_trans(eps,N,liststrucSU3)

SU_pi = apply_trans(SU_trans,pi)
SU_dpi = apply_trans(SU_trans,dpi)


# Get potential values, only care about real part (non zero imag should just be numerical precision errors)

orig_V = cL.get_V(pi,dpi,gens,F0).real
SO_V = cL.get_V(SO_pi,SO_dpi,gens,F0).real
SU_V = cL.get_V(SU_pi,SU_dpi,gens,F0).real

SO_Vdiff = (SO_V - orig_V)/orig_V
SU_Vdiff = (SU_V - orig_V)/orig_V

rand_means = np.mean(np.hstack([np.abs(pi) , np.abs(dpi)]),axis=-1)

# %%
print("Average error of SU(3) transformation: ",np.mean(np.abs(SU_Vdiff)),
      ", and of rotation: ",np.mean(np.abs(SO_Vdiff)))

print("Average potential value: ",np.mean(np.abs(orig_V)),", average pion value:",np.mean(rand_means))
# Out:
# Average error of SU(3) transformation:  359433.83740378224 , and of rotation:  98818.14813138814
# Average potential value:  0.19447662499892343 , average pion value: 0.5000079982487028

# %%
# Standard error by hand to compare with seaborn lineplot

fig,ax = plt.subplots(1,figsize=(9,6))

# Evaluate std deviation is epsilon is created using interval
SO_Vdiff_eps = [np.abs(SO_Vdiff[np.where(eps==val)]) for val in eps_vals]
mean_SO = np.mean(SO_Vdiff_eps,axis=-1)
std_dev_SO = np.std(SO_Vdiff_eps,axis=-1)
std_error_SO = std_dev_SO/np.sqrt([len(s) for s in SO_Vdiff_eps])
SU_Vdiff_eps = [np.abs(SU_Vdiff[np.where(eps==val)]) for val in eps_vals]
mean_SU = np.mean(SU_Vdiff_eps,axis=-1)
std_dev_SU = np.std(SU_Vdiff_eps,axis=-1)
std_error_SU = std_dev_SU/np.sqrt([len(s) for s in SU_Vdiff_eps])
#print(std_dev_SU)

#print(std_error_SU)
ax.plot(eps_vals,mean_SO,marker='.',label='SO({:})'.format(N*N-1))
ax.plot(eps_vals,mean_SU,marker='.',label='SU({:})'.format(N))
Range = 1
ax.fill_between(eps_vals,mean_SO-Range*std_error_SO, mean_SO+Range*std_error_SO,color='blue',alpha=0.5)
ax.fill_between(eps_vals,mean_SU-Range*std_error_SU, mean_SU+Range*std_error_SU,color='orange',alpha=0.5)

ax.set_xlabel(r'$\epsilon$')
ax.set_ylabel(r'$\Delta V$')
ax.set_xscale('log')
ax.set_yscale('log')
ax.legend()
ax.set_ylim(1e-7,1)
ax.set_xlim(1e-3,1)

#fig.tight_layout()
#fig.savefig('DeltaV.png',dpi=200)
# Out:
# (0.001, 1)

# %%
###Find offsets so fit lines line up
so_grad, so_intercept,_,_,_ = stats.linregress(eps_vals,abs(mean_SO))
su_intercept = 10**stats.linregress(np.log10(eps_vals),np.log10(abs(mean_SU)))[0]

# %%
fig,ax = plt.subplots(1,figsize=(10,6))


data = pd.DataFrame({'epsilon':eps,'SOdiff':np.abs(SO_Vdiff),'SUdiff':np.abs(SU_Vdiff)})
data
sb.lineplot(data=data,x='epsilon',y='SOdiff',label='SO({:})'.format(N*N-1),ci=99,color = 'black' )
sb.lineplot(data=data,x='epsilon',y='SUdiff',label='SU({:})'.format(N),ci=99, color = 'Red')



x = np.logspace(-3,1,100)
y1 = np.exp(x)-(1+x)
y = 1/(1-x)-(1)
#ax.plot(x,y,color="green")
ax.plot(x,x*0.4,color="Black",linestyle='--')
ax.grid(False)
#ax.plot(x,y1,color="orange")
ax.plot(x,(x**2)*0.7,color="Red",linestyle='--',linewidth = 1)


ax.set_xlabel(r'$\epsilon$')
ax.set_ylabel(r'$\Delta V$')
ax.set_xscale('log')
ax.set_yscale('log')
ax.grid(False)
ax.legend()
ax.set_ylim(1e-7,100)
ax.set_xlim(1e-3,10)
fig.tight_layout()
fig.savefig('DeltaV_no_noise.png',dpi=300,transparent=False)

# %%
data.to_csv('./Data/symetric_training_data_epsilon_and_vdiff.csv')

# %%
data =  cf.noisy(0).data(10**5, 0.25,cutoff = 0.1)
# Out:
# Training data cut for potential values below 0.1
# Remaining data fraction after cut  = 0.58032
# To retain 100000 training points generating 72955 more
# This produces 100369 usefull points

# %%
from sklearn.model_selection import train_test_split as tts
train_x,val_x,train_y,val_y = tts(data[:,:-1],data[:,-1],test_size = 0.1)

# %%
inital_model = models.Sequential()
inital_model.add(layers.Input(train_x.shape[1]))
inital_model.add(layers.Dense(60,activation='relu'))
inital_model.add(layers.Dense(60,activation='relu'))
inital_model.add(layers.Dense(1))
inital_model.compile(optimizer = 'Adam',loss = 'mape', metrics = [['mean_absolute_error'],['mean_absolute_percentage_error']])
inital_model.summary()

epochs = 50
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense (Dense)                (None, 60)                1020
# _________________________________________________________________
# dense_1 (Dense)              (None, 60)                3660
# _________________________________________________________________
# dense_2 (Dense)              (None, 1)                 61
# =================================================================
# Total params: 4,741
# Trainable params: 4,741
# Non-trainable params: 0
# _________________________________________________________________
# 2022-03-25 07:47:25.300923: E tensorflow/stream_executor/cuda/cuda_driver.cc:271] failed call to cuInit: CUDA_ERROR_NO_DEVICE: no CUDA-capable device is detected
# 2022-03-25 07:47:25.300957: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:169] retrieving CUDA diagnostic information for host: Sean-PC
# 2022-03-25 07:47:25.300964: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:176] hostname: Sean-PC
# 2022-03-25 07:47:25.301108: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:200] libcuda reported version is: 470.103.1
# 2022-03-25 07:47:25.301131: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:204] kernel reported version is: 470.103.1
# 2022-03-25 07:47:25.301136: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:310] kernel version seems to match DSO: 470.103.1
# 2022-03-25 07:47:25.301425: I tensorflow/core/platform/cpu_feature_guard.cc:142] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
history = inital_model.fit(train_x,train_y,validation_data = (val_x,val_y),batch_size= 256, epochs =epochs)
# Out:
# 2022-03-25 07:47:25.377705: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:185] None of the MLIR Optimization Passes are enabled (registered 2)
# Epoch 1/50
# 352/352 [==============================] - 1s 924us/step - loss: 30.1073 - mean_absolute_error: 0.0657 - mean_absolute_percentage_error: 30.1073 - val_loss: 21.9075 - val_mean_absolute_error: 0.0504 - val_mean_absolute_percentage_error: 21.9075
# Epoch 2/50
# 352/352 [==============================] - 0s 740us/step - loss: 17.8421 - mean_absolute_error: 0.0381 - mean_absolute_percentage_error: 17.8421 - val_loss: 14.2350 - val_mean_absolute_error: 0.0295 - val_mean_absolute_percentage_error: 14.2350
# Epoch 3/50
# 352/352 [==============================] - 0s 674us/step - loss: 13.4909 - mean_absolute_error: 0.0275 - mean_absolute_percentage_error: 13.4909 - val_loss: 12.1979 - val_mean_absolute_error: 0.0240 - val_mean_absolute_percentage_error: 12.1979
# Epoch 4/50
# 352/352 [==============================] - 0s 707us/step - loss: 11.9232 - mean_absolute_error: 0.0239 - mean_absolute_percentage_error: 11.9232 - val_loss: 10.4876 - val_mean_absolute_error: 0.0220 - val_mean_absolute_percentage_error: 10.4876
# Epoch 5/50
# 352/352 [==============================] - 0s 711us/step - loss: 10.9973 - mean_absolute_error: 0.0219 - mean_absolute_percentage_error: 10.9973 - val_loss: 10.4090 - val_mean_absolute_error: 0.0219 - val_mean_absolute_percentage_error: 10.4090
# Epoch 6/50
# 352/352 [==============================] - 0s 705us/step - loss: 10.3241 - mean_absolute_error: 0.0205 - mean_absolute_percentage_error: 10.3241 - val_loss: 11.1275 - val_mean_absolute_error: 0.0208 - val_mean_absolute_percentage_error: 11.1275
# Epoch 7/50
# 352/352 [==============================] - 0s 689us/step - loss: 10.0651 - mean_absolute_error: 0.0199 - mean_absolute_percentage_error: 10.0651 - val_loss: 9.4321 - val_mean_absolute_error: 0.0194 - val_mean_absolute_percentage_error: 9.4321
# Epoch 8/50
# 352/352 [==============================] - 0s 715us/step - loss: 10.0541 - mean_absolute_error: 0.0197 - mean_absolute_percentage_error: 10.0541 - val_loss: 9.0881 - val_mean_absolute_error: 0.0182 - val_mean_absolute_percentage_error: 9.0881
# Epoch 9/50
# 352/352 [==============================] - 0s 716us/step - loss: 9.3430 - mean_absolute_error: 0.0185 - mean_absolute_percentage_error: 9.3430 - val_loss: 9.8107 - val_mean_absolute_error: 0.0202 - val_mean_absolute_percentage_error: 9.8107
# Epoch 10/50
# 352/352 [==============================] - 0s 666us/step - loss: 9.3874 - mean_absolute_error: 0.0185 - mean_absolute_percentage_error: 9.3874 - val_loss: 9.3389 - val_mean_absolute_error: 0.0184 - val_mean_absolute_percentage_error: 9.3389
# Epoch 11/50
# 352/352 [==============================] - 0s 695us/step - loss: 9.4273 - mean_absolute_error: 0.0185 - mean_absolute_percentage_error: 9.4273 - val_loss: 8.8064 - val_mean_absolute_error: 0.0174 - val_mean_absolute_percentage_error: 8.8064
# Epoch 12/50
# 352/352 [==============================] - 0s 661us/step - loss: 8.9455 - mean_absolute_error: 0.0176 - mean_absolute_percentage_error: 8.9455 - val_loss: 8.7473 - val_mean_absolute_error: 0.0172 - val_mean_absolute_percentage_error: 8.7473
# Epoch 13/50
# 352/352 [==============================] - 0s 701us/step - loss: 8.8224 - mean_absolute_error: 0.0173 - mean_absolute_percentage_error: 8.8224 - val_loss: 9.7144 - val_mean_absolute_error: 0.0198 - val_mean_absolute_percentage_error: 9.7144
# Epoch 14/50
# 352/352 [==============================] - 0s 706us/step - loss: 8.8326 - mean_absolute_error: 0.0173 - mean_absolute_percentage_error: 8.8326 - val_loss: 8.0763 - val_mean_absolute_error: 0.0164 - val_mean_absolute_percentage_error: 8.0763
# Epoch 15/50
# 352/352 [==============================] - 0s 675us/step - loss: 8.5225 - mean_absolute_error: 0.0168 - mean_absolute_percentage_error: 8.5225 - val_loss: 7.7798 - val_mean_absolute_error: 0.0158 - val_mean_absolute_percentage_error: 7.7798
# Epoch 16/50
# 352/352 [==============================] - 0s 684us/step - loss: 8.5449 - mean_absolute_error: 0.0168 - mean_absolute_percentage_error: 8.5449 - val_loss: 7.7141 - val_mean_absolute_error: 0.0155 - val_mean_absolute_percentage_error: 7.7141
# Epoch 17/50
# 352/352 [==============================] - 0s 686us/step - loss: 8.3296 - mean_absolute_error: 0.0164 - mean_absolute_percentage_error: 8.3296 - val_loss: 7.6035 - val_mean_absolute_error: 0.0156 - val_mean_absolute_percentage_error: 7.6035
# Epoch 18/50
# 352/352 [==============================] - 0s 686us/step - loss: 8.1761 - mean_absolute_error: 0.0161 - mean_absolute_percentage_error: 8.1761 - val_loss: 7.7818 - val_mean_absolute_error: 0.0155 - val_mean_absolute_percentage_error: 7.7818
# Epoch 19/50
# 352/352 [==============================] - 0s 654us/step - loss: 8.0561 - mean_absolute_error: 0.0159 - mean_absolute_percentage_error: 8.0561 - val_loss: 8.0456 - val_mean_absolute_error: 0.0156 - val_mean_absolute_percentage_error: 8.0456
# Epoch 20/50
# 352/352 [==============================] - 0s 684us/step - loss: 7.8101 - mean_absolute_error: 0.0155 - mean_absolute_percentage_error: 7.8101 - val_loss: 8.1535 - val_mean_absolute_error: 0.0156 - val_mean_absolute_percentage_error: 8.1535
# Epoch 21/50
# 352/352 [==============================] - 0s 698us/step - loss: 8.0674 - mean_absolute_error: 0.0159 - mean_absolute_percentage_error: 8.0674 - val_loss: 9.1435 - val_mean_absolute_error: 0.0187 - val_mean_absolute_percentage_error: 9.1435
# Epoch 22/50
# 352/352 [==============================] - 0s 684us/step - loss: 7.9327 - mean_absolute_error: 0.0156 - mean_absolute_percentage_error: 7.9327 - val_loss: 7.9992 - val_mean_absolute_error: 0.0154 - val_mean_absolute_percentage_error: 7.9992
# Epoch 23/50
# 352/352 [==============================] - 0s 686us/step - loss: 7.7990 - mean_absolute_error: 0.0154 - mean_absolute_percentage_error: 7.7990 - val_loss: 7.5378 - val_mean_absolute_error: 0.0156 - val_mean_absolute_percentage_error: 7.5378
# Epoch 24/50
# 352/352 [==============================] - 0s 695us/step - loss: 7.5719 - mean_absolute_error: 0.0150 - mean_absolute_percentage_error: 7.5719 - val_loss: 7.7653 - val_mean_absolute_error: 0.0159 - val_mean_absolute_percentage_error: 7.7653
# Epoch 25/50
# 352/352 [==============================] - 0s 703us/step - loss: 7.6562 - mean_absolute_error: 0.0151 - mean_absolute_percentage_error: 7.6562 - val_loss: 7.2283 - val_mean_absolute_error: 0.0147 - val_mean_absolute_percentage_error: 7.2283
# Epoch 26/50
# 352/352 [==============================] - 0s 673us/step - loss: 7.5337 - mean_absolute_error: 0.0149 - mean_absolute_percentage_error: 7.5337 - val_loss: 8.9824 - val_mean_absolute_error: 0.0165 - val_mean_absolute_percentage_error: 8.9824
# Epoch 27/50
# 352/352 [==============================] - 0s 683us/step - loss: 7.5010 - mean_absolute_error: 0.0148 - mean_absolute_percentage_error: 7.5010 - val_loss: 7.0475 - val_mean_absolute_error: 0.0140 - val_mean_absolute_percentage_error: 7.0475
# Epoch 28/50
# 352/352 [==============================] - 0s 723us/step - loss: 7.3766 - mean_absolute_error: 0.0146 - mean_absolute_percentage_error: 7.3766 - val_loss: 9.3532 - val_mean_absolute_error: 0.0186 - val_mean_absolute_percentage_error: 9.3532
# Epoch 29/50
# 352/352 [==============================] - 0s 685us/step - loss: 7.3822 - mean_absolute_error: 0.0146 - mean_absolute_percentage_error: 7.3822 - val_loss: 6.9358 - val_mean_absolute_error: 0.0142 - val_mean_absolute_percentage_error: 6.9358
# Epoch 30/50
# 352/352 [==============================] - 0s 689us/step - loss: 7.2179 - mean_absolute_error: 0.0143 - mean_absolute_percentage_error: 7.2179 - val_loss: 7.1309 - val_mean_absolute_error: 0.0146 - val_mean_absolute_percentage_error: 7.1309
# Epoch 31/50
# 352/352 [==============================] - 0s 694us/step - loss: 7.1947 - mean_absolute_error: 0.0142 - mean_absolute_percentage_error: 7.1947 - val_loss: 7.0275 - val_mean_absolute_error: 0.0139 - val_mean_absolute_percentage_error: 7.0275
# Epoch 32/50
# 352/352 [==============================] - 0s 691us/step - loss: 7.2047 - mean_absolute_error: 0.0142 - mean_absolute_percentage_error: 7.2047 - val_loss: 6.7550 - val_mean_absolute_error: 0.0138 - val_mean_absolute_percentage_error: 6.7550
# Epoch 33/50
# 352/352 [==============================] - 0s 667us/step - loss: 7.2012 - mean_absolute_error: 0.0142 - mean_absolute_percentage_error: 7.2012 - val_loss: 6.9800 - val_mean_absolute_error: 0.0144 - val_mean_absolute_percentage_error: 6.9800
# Epoch 34/50
# 352/352 [==============================] - 0s 671us/step - loss: 7.0629 - mean_absolute_error: 0.0140 - mean_absolute_percentage_error: 7.0629 - val_loss: 6.8161 - val_mean_absolute_error: 0.0141 - val_mean_absolute_percentage_error: 6.8161
# Epoch 35/50
# 352/352 [==============================] - 0s 679us/step - loss: 7.1888 - mean_absolute_error: 0.0142 - mean_absolute_percentage_error: 7.1888 - val_loss: 6.7785 - val_mean_absolute_error: 0.0135 - val_mean_absolute_percentage_error: 6.7785
# Epoch 36/50
# 352/352 [==============================] - 0s 671us/step - loss: 6.8795 - mean_absolute_error: 0.0137 - mean_absolute_percentage_error: 6.8795 - val_loss: 7.0497 - val_mean_absolute_error: 0.0144 - val_mean_absolute_percentage_error: 7.0497
# Epoch 37/50
# 352/352 [==============================] - 0s 656us/step - loss: 7.0105 - mean_absolute_error: 0.0138 - mean_absolute_percentage_error: 7.0105 - val_loss: 9.3065 - val_mean_absolute_error: 0.0168 - val_mean_absolute_percentage_error: 9.3065
# Epoch 38/50
# 352/352 [==============================] - 0s 685us/step - loss: 6.8797 - mean_absolute_error: 0.0136 - mean_absolute_percentage_error: 6.8797 - val_loss: 9.0081 - val_mean_absolute_error: 0.0165 - val_mean_absolute_percentage_error: 9.0081
# Epoch 39/50
# 352/352 [==============================] - 0s 669us/step - loss: 6.9025 - mean_absolute_error: 0.0137 - mean_absolute_percentage_error: 6.9025 - val_loss: 7.5851 - val_mean_absolute_error: 0.0156 - val_mean_absolute_percentage_error: 7.5851
# Epoch 40/50
# 352/352 [==============================] - 0s 661us/step - loss: 6.8636 - mean_absolute_error: 0.0136 - mean_absolute_percentage_error: 6.8636 - val_loss: 6.8803 - val_mean_absolute_error: 0.0135 - val_mean_absolute_percentage_error: 6.8803
# Epoch 41/50
# 352/352 [==============================] - 0s 681us/step - loss: 6.8020 - mean_absolute_error: 0.0135 - mean_absolute_percentage_error: 6.8020 - val_loss: 7.9461 - val_mean_absolute_error: 0.0148 - val_mean_absolute_percentage_error: 7.9461
# Epoch 42/50
# 352/352 [==============================] - 0s 685us/step - loss: 6.8358 - mean_absolute_error: 0.0135 - mean_absolute_percentage_error: 6.8358 - val_loss: 6.7560 - val_mean_absolute_error: 0.0137 - val_mean_absolute_percentage_error: 6.7560
# Epoch 43/50
# 352/352 [==============================] - 0s 663us/step - loss: 6.5750 - mean_absolute_error: 0.0131 - mean_absolute_percentage_error: 6.5750 - val_loss: 7.8798 - val_mean_absolute_error: 0.0148 - val_mean_absolute_percentage_error: 7.8798
# Epoch 44/50
# 352/352 [==============================] - 0s 683us/step - loss: 6.6715 - mean_absolute_error: 0.0132 - mean_absolute_percentage_error: 6.6715 - val_loss: 7.3961 - val_mean_absolute_error: 0.0141 - val_mean_absolute_percentage_error: 7.3961
# Epoch 45/50
# 352/352 [==============================] - 0s 670us/step - loss: 6.7267 - mean_absolute_error: 0.0133 - mean_absolute_percentage_error: 6.7267 - val_loss: 7.6216 - val_mean_absolute_error: 0.0154 - val_mean_absolute_percentage_error: 7.6216
# Epoch 46/50
# 352/352 [==============================] - 0s 683us/step - loss: 6.6066 - mean_absolute_error: 0.0131 - mean_absolute_percentage_error: 6.6066 - val_loss: 6.3878 - val_mean_absolute_error: 0.0131 - val_mean_absolute_percentage_error: 6.3878
# Epoch 47/50
# 352/352 [==============================] - 0s 702us/step - loss: 6.5132 - mean_absolute_error: 0.0129 - mean_absolute_percentage_error: 6.5132 - val_loss: 6.3183 - val_mean_absolute_error: 0.0128 - val_mean_absolute_percentage_error: 6.3183
# Epoch 48/50
# 352/352 [==============================] - 0s 688us/step - loss: 6.5596 - mean_absolute_error: 0.0129 - mean_absolute_percentage_error: 6.5596 - val_loss: 6.3440 - val_mean_absolute_error: 0.0126 - val_mean_absolute_percentage_error: 6.3440
# Epoch 49/50
# 352/352 [==============================] - 0s 666us/step - loss: 6.4544 - mean_absolute_error: 0.0128 - mean_absolute_percentage_error: 6.4544 - val_loss: 6.9552 - val_mean_absolute_error: 0.0139 - val_mean_absolute_percentage_error: 6.9552
# Epoch 50/50
# 352/352 [==============================] - 0s 698us/step - loss: 6.4374 - mean_absolute_error: 0.0127 - mean_absolute_percentage_error: 6.4374 - val_loss: 6.0776 - val_mean_absolute_error: 0.0123 - val_mean_absolute_percentage_error: 6.0776

# %%
validation_MAPE = history.history['val_mean_absolute_percentage_error']
MAPE = history.history['loss']

# %%
matplotlib.rcParams.update({'legend.fontsize': 26})
matplotlib.rcParams.update({'font.size': 26})
epochs = range(1,len(validation_MAPE)+1)
fig,ax  = plt.subplots(1,1,figsize = (10,8))
ax.plot(epochs,validation_MAPE,c = 'red',linestyle = '--',label = r'\textbf{Validation MAPE}')
ax.plot(epochs,MAPE,c = 'black',label = r'\textbf{Loss}')
ax.set_xlabel(r'\textbf{Training Epochs}')
ax.legend()
ax.set_ylabel(r'\textbf{Mean Absolute Percentage Error}')
fig.savefig('/home/sean/Documents/Work/Level 4/Level-4-Masters-Project/Figures/inital_net.png',dpi = 400)

# %%
test_data= cf.gen_and_load(10**6,0)

# %%
### Generate New test data for nn prediction
pi_dpi,v = test_data[1]
pis =pi_dpi[:,:8]
dpis = pi_dpi[:,8:]

SU_dpi_nn = apply_trans(SU_trans,dpis)
SU_pi_nn = apply_trans(SU_trans,pis)
SU_pi_dpi_nn = np.hstack((SU_pi_nn,SU_dpi_nn))
SU_V_nn_test = cL.get_V(SU_pi_nn,SU_dpi_nn,gens,F0).real


SO_dpi_nn = apply_trans(SO_trans,dpis)
SO_pi_nn = apply_trans(SO_trans,pis)
SO_pi_dpi_nn = np.hstack((SO_pi_nn,SO_dpi_nn))
SO_V_nn_test = cL.get_V(SO_pi_nn,SO_dpi_nn,gens,F0).real

###I only want the transformed data on the interval 0-1

# %%
print('Range of Pi\' fields',np.min(SU_pi_dpi_nn),'to',np.max(SU_pi_dpi_nn))
print('Mean Pi\' Field', np.mean(SU_pi_dpi_nn))
print('Range of Pi fields',np.min(pi_dpi),'to',np.max(pi_dpi))
# Out:
# Range of Pi' fields -135.45790419124762 to 136.54860690713852
# Mean Pi' Field 0.7995114353317503
# Range of Pi fields 0.010124042281656477 to 0.9999999983122357

# %%
fig , ax = plt.subplots(2,8,sharey= True, figsize = (10,8))
plt.subplots_adjust(hspace= 0.4,wspace= 0.5)
for i in range(8):
    ax[0,i].hist(SU_pi_dpi_nn[:,i], density = True, color = 'black') 
    #ax[0,i].set_xticks([0,1])
    #ax[1,i].set_xticks([0,1])
    ax[1,i].hist(SU_pi_dpi_nn[:,8+i],density = True, color = 'black')
    ax[0,i].set_xlabel('$\phi_{{{}}}$'.format(i))
    ax[1,i].set_xlabel('$d\phi_{{{}}}$'.format(i))
fig.supylabel('Frequency Density')
fig_2 = plt.figure(figsize= (10,8))
plt.hist(abs(SU_V_nn_test),density= True, bins = 1000, color = 'black',label=  '$\phi \sim U^{1/4}$')
#plt.hist(df_SU_pi_dpi_nn[:,-1],density= True, bins = 1000, color = 'blue',label=  '$\phi \sim U^{1/4}$' )
plt.xlabel('$V(\phi)$')
plt.ylabel('Frequency Density')
plt.xlim(0,10**5)
plt.legend()

# %%
cf.field_plotter(pi_dpi,v)

# %% [markdown]
# I think that I am using a different dataset for the Numeric transform data

# %%
#Use Neural network to predict transformation
#Delta Vnn calculated for plotting 
V_nn = inital_model.predict(SU_pi_dpi_nn)
V_nn_SO = inital_model.predict(SO_pi_dpi_nn)
delta_V_nn = abs((V_nn[:,0]-v)/v)
delta_V_nn_SO =abs((V_nn_SO[:,0]-v)/v)

V_nn.shape
# Out:
# (1000000, 1)

# %%
fig,ax = plt.subplots(1,figsize=(10,8))

matplotlib.rcParams.update({'legend.fontsize': 26})
matplotlib.rcParams.update({'font.size': 26})
matplotlib.rcParams.update({'font.weight': 'bold'})

data = pd.DataFrame({'epsilon':eps,'SOdiff':np.abs(SO_Vdiff),'SUdiff':np.abs(SU_Vdiff),'SUdiff_nn':np.abs(delta_V_nn),'SOdiff_nn':np.abs(delta_V_nn_SO)})
sb.lineplot(data=data,x='epsilon',y='SOdiff',label=r'\textbf{SO(8)'            ,ci=95,color = 'black' )
sb.lineplot(data=data,x='epsilon',y='SUdiff',label=r'\textbf{SU(3)'                ,ci=95, color = 'Red')
sb.lineplot(data=data,x='epsilon',y='SUdiff_nn',label=r'\textbf{SO(8$)_{nn}$}' ,ci=95, color = 'Purple')
sb.lineplot(data=data,x='epsilon',y='SOdiff_nn',label=r'\textbf{SU(3$)_{nn}$}',ci=95, color = 'Blue')

x = np.logspace(-3,1,100)
y1 = np.exp(x)-(1+x)
y = 1/(1-x)-(1)
#ax.plot(x,y,color="green")
ax.plot(x,x*0.4,color="Black",linestyle='--')
ax.grid(False)
#ax.plot(x,y1,color="orange")
ax.plot(x,(x**2)*0.7,color="Red",linestyle='--',linewidth = 1)
ax.plot(x,np.ones_like(x)*np.min(validation_MAPE)/100, color = 'grey',linestyle = '--', label = r'\textbf{Network MAPE}')

ax.set_xlabel(r'$\epsilon$')
ax.set_ylabel(r'$\Delta V$')
ax.set_xscale('log')
ax.set_yscale('log')
ax.grid(False)
ax.legend()
ax.set_ylim(1e-3,10)
ax.set_xlim(1e-3,10)
fig.tight_layout()
fig.savefig('/home/sean/Documents/Work/Level 4/Level-4-Masters-Project/Figures/DeltaV_inital_1.png',dpi=400,transparent=True)

# %%
model = keras.models.load_model('/home/sean/Documents/Work/Level 4/Level-4-Masters-Project/Hyperparam_Testing/Testing_Notebooks/Optimised_Network/Saved_Optimised_Networks/5_107.0datapoints.h5')

# %%
pred_V =  model.predict(pi_dpi)[:,0]
MAPE = np.mean(abs((pred_V - v)/v))
print('MAPE = ',round(MAPE*100,2))
# Out:
# MAPE =  1.24

# %%
V_nn = model.predict(SU_pi_dpi_nn)
#print(V_nn)
#print(V_nn[:,0].shape)
delta_V_nn = abs((V_nn[:,0]-v)/v)

SO_pi =  apply_trans(SO_trans,pis)
SO_dpi = apply_trans(SO_trans,dpis)
SO_pi_dpi_nn = np.hstack((SO_pi,SO_dpi))

V_nn_SO = model.predict(SO_pi_dpi_nn)


delta_V_nn_SO = abs((V_nn_SO[:,0]-v)/v)

# %%
confidence_inteval = 96

fig_2,ax = plt.subplots(1,figsize=(8,6))
data = pd.DataFrame({'epsilon':eps,'SOdiff':np.abs(SO_Vdiff),'SUdiff':np.abs(SU_Vdiff),'SUdiff_nn':np.abs(delta_V_nn),'SOdiff_nn':np.abs(delta_V_nn_SO)})
sb.lineplot(data=data,x='epsilon',y='SOdiff',label='SO({:})'.format(N*N-1),ci = confidence_inteval,color = 'black' )
sb.lineplot(data=data,x='epsilon',y='SUdiff',label='SU({:})'.format(N),ci=confidence_inteval, color = 'Red')
sb.lineplot(data=data,x='epsilon',y='SUdiff_nn',label='SU({}'.format(N)+'$)_{nn}$',ci=confidence_inteval, color = 'Purple')
sb.lineplot(data=data,x='epsilon',y='SOdiff_nn',label='SO({}'.format(N*N-1)+'$)_{nn}$',ci=confidence_inteval, color = 'Blue')

x = np.logspace(-3,1,100)
y1 = np.exp(x)-(1+x)
y = 1/(1-x)-(1)
#ax.plot(x,y,color="green")
ax.plot(x,x*0.4,color="Black",linestyle='--')
ax.grid(False)
#ax.plot(x,y1,color="orange")
ax.plot(x,(x**2)*0.7,color="Red",linestyle='--',linewidth = 1)
#ax.plot(x,np.ones_like(x)*MAPE, color = 'purple',linestyle = '--', label = 'Network MAPE')

ax.set_xlabel(r'$\epsilon$')
ax.set_ylabel(r'$\Delta V$')
ax.set_xscale('log')
ax.set_yscale('log')
ax.grid(False)
ax.legend()
ax.set_ylim(1e-3,10)
ax.set_xlim(1e-3,10)
fig_2.tight_layout()

# %%
import time 
time = datetime.date.today()

fig_2.savefig('/home/sean/Documents/Work/Level 4/Level-4-Masters-Project/Figures/DeltaV_improved_{}.jpeg'.format(time),dpi=300,transparent=False)

# %%
coef_su = np.polyfit(eps_vals, mean_SU,3)
for i,ii in enumerate(coef_su):
    print('a{}'.format(i)+'='+str(ii))
# Out:
# a0=28.403409310950806
# a1=-1485.9010704683033
# a2=21519.040694171348
# a3=-15915.98839513543

# %%
plt.loglog(eps_vals,np.mean([np.abs(delta_V_nn[np.where(eps==val)]) for val in eps_vals],axis = 1))

# %%
fig,ax = plt.subplots(1,figsize=(9,6))

SO_Vdiff_eps = [np.abs(SO_Vdiff[np.where(eps==val)]) for val in eps_vals] ##subsampling only the points which have epsilon values
mean_SO = np.mean(SO_Vdiff_eps,axis=-1)
std_dev_SO = np.std(SO_Vdiff_eps,axis=-1)
std_error_SO = std_dev_SO/np.sqrt([len(s) for s in SO_Vdiff_eps])
SU_Vdiff_eps = [np.abs(SU_Vdiff[np.where(eps==val)]) for val in eps_vals]
mean_SU = np.mean(SU_Vdiff_eps,axis=-1)
std_dev_SU = np.std(SU_Vdiff_eps,axis=-1)
std_error_SU = std_dev_SU/np.sqrt([len(s) for s in SU_Vdiff_eps])
nn_eps = [np.abs(delta_V_nn[np.where(eps==val)]) for val in eps_vals]
mean_nn = np.mean(nn_eps,axis = -1)
std_nn = np.std(nn_eps,axis =-1)
ste_nn = std_nn/np.sqrt([len(s) for s in nn_eps])

nn_eps_SO  = [np.abs(delta_V_nn_SO[np.where(eps==val)]) for val in eps_vals]
mean_nn_SO = np.mean(nn_eps_SO,axis = -1)
std_nn_SO  = np.std( nn_eps_SO ,axis =-1)
ste_nn_SO  = std_nn_SO/np.sqrt([len(s) for s in nn_eps])




ax.plot(eps_vals,mean_SO,marker='',label='SO({:})'.format(N*N-1),c = 'black',linewidth = 0.8)
ax.plot(eps_vals,mean_SU,marker='',label='SU({:})'.format(N),c = 'red',linewidth = 0.8)
ax.plot(eps_vals,mean_nn,marker='',label='SU({:}'.format(N)+'$)_{nn}$', color = 'purple',linewidth = 0.8)
Range = 1
ax.fill_between(eps_vals,mean_SO-Range*std_error_SO, mean_SO+Range*std_error_SO,color='black',linewidth = 0.6,alpha=0.3)
ax.fill_between(eps_vals,mean_SU-Range*std_error_SU, mean_SU+Range*std_error_SU,color='red',linewidth = 0.6,alpha=0.3)
ax.fill_between(eps_vals,mean_nn-Range*ste_nn, mean_nn+Range*ste_nn,color='purple',alpha=0.3,)

ax.set_xlabel(r'$\epsilon$')
ax.set_ylabel(r'$\Delta V$')
ax.set_xscale('log')
ax.set_yscale('log')
ax.legend()
ax.set_ylim(1e-3,10)
ax.set_xlim(1e-3,10)
# Out:
# (0.001, 10)

# %%
fig, ax = plt.subplots()
mean_nn.shape
ax.plot(eps_vals,mean_SO)
ax.set_ylim(1e-3,1)
ax.set_xlim(1e-3,1)
# Out:
# (0.001, 1.0)

# %%
# Create windows
def p5(x,a0,a1,a2):
    return a0+x*a1+a2*x**2

p0 = [0,0,1]
window = 50
step=1

eps_windowed = sliding_window_view(eps_vals,window)[::step]
mean_SO_windowed = sliding_window_view(mean_SO,window)[::step]
mean_SU_windowed = sliding_window_view(mean_SU,window)[::step]
#mean_arb_windowed = sliding_window_view(mean_arb,window)[::step]

mean_SO_network_windowed = sliding_window_view(mean_nn_SO,window)[::step]
mean_SU_network_windowed = sliding_window_view(mean_nn,window)[::step]
#mean_arb_network_windowed = sliding_window_view(mean_arb_network,window)[::step]


std_error_SO_windowed = sliding_window_view(std_error_SO,window)[::step]
std_error_SU_windowed = sliding_window_view(std_error_SU,window)[::step]
#std_error_arb_windowed = sliding_window_view(std_error_arb,window)[::step]

std_error_SO_network_windowed = sliding_window_view(ste_nn_SO,window)[::step]
std_error_SU_network_windowed = sliding_window_view(ste_nn,window)[::step]
#td_error_arb_network_windowed = sliding_window_view(std_error_arb_network,window)[::step]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_10457/3219789403.py in <module>
#      12 #mean_arb_windowed = sliding_window_view(mean_arb,window)[::step]
#      13
# ---> 14 mean_SO_network_windowed = sliding_window_view(mean_nn_SO,window)[::step]
#      15 mean_SU_network_windowed = sliding_window_view(mean_nn,window)[::step]
#      16 #mean_arb_network_windowed = sliding_window_view(mean_arb_network,window)[::step]
#
# NameError: name 'mean_nn_SO' is not defined

# %%
SO_fits=np.zeros((eps_windowed.shape[0],len(p0)))
SU_fits=np.zeros((eps_windowed.shape[0],len(p0)))
arb_fits=np.zeros((eps_windowed.shape[0],len(p0)))

SO_network_fits=np.zeros((eps_windowed.shape[0],len(p0)))
SU_network_fits=np.zeros((eps_windowed.shape[0],len(p0)))
arb_network_fits=np.zeros((eps_windowed.shape[0],len(p0)))


SO_covs=np.zeros((eps_windowed.shape[0],len(p0),len(p0)))
SU_covs=np.zeros((eps_windowed.shape[0],len(p0),len(p0)))
#arb_covs=np.zeros((eps_windowed.shape[0],len(p0),len(p0)))

SO_network_covs=np.zeros((eps_windowed.shape[0],len(p0),len(p0)))
SU_network_covs=np.zeros((eps_windowed.shape[0],len(p0),len(p0)))
#arb_network_covs=np.zeros((eps_windowed.shape[0],len(p0),len(p0)))

bound = (-0.001,10)
for i,these_eps_vals in enumerate(eps_windowed):
    #print(i/len(eps_windowed))
    SO_fit_params,SO_fit_cov=fit(p5,these_eps_vals,mean_SO_windowed[i],p0=p0,
                                                      sigma=std_error_SO_windowed[i],absolute_sigma=True,bounds=bound)
    SU_fit_params,SU_fit_cov=fit(p5,these_eps_vals,mean_SU_windowed[i],p0=p0,
                                                      sigma=std_error_SU_windowed[i],absolute_sigma=True,bounds=bound)
    
    
    SU_network_fit_params,SU_network_fit_cov=fit(p5,these_eps_vals,mean_SU_network_windowed[i],
                                                                    p0=p0,sigma=std_error_SU_network_windowed[i],absolute_sigma=True,
                                                                    bounds=bound)
    SO_network_fit_params,SO_network_fit_cov=fit(p5,these_eps_vals,mean_SO_network_windowed[i],
                                                                    p0=p0,sigma=std_error_SO_network_windowed[i],absolute_sigma=True,
                                                                    bounds=bound)
    



    SO_fits[i]=(SO_fit_params)
    SO_covs[i]=(SO_fit_cov)
    SU_fits[i]=(SU_fit_params)
    SU_covs[i]=(SU_fit_cov)
    

    SO_network_fits[i]=(SO_network_fit_params)
    SO_network_covs[i]=(SO_network_fit_cov)
    SU_network_fits[i]=(SU_network_fit_params)
    SU_network_covs[i]=(SU_network_fit_cov)
    #arb_network_fits[i]=(arb_network_fit_params)
    #arb_network_covs[i]=(arb_network_fit_cov)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_10457/3517414836.py in <module>
#      20     #print(i/len(eps_windowed))
#      21     SO_fit_params,SO_fit_cov=fit(p5,these_eps_vals,mean_SO_windowed[i],p0=p0,
# ---> 22                                                       sigma=std_error_SO_windowed[i],absolute_sigma=True,bounds=bound)
#      23     SU_fit_params,SU_fit_cov=fit(p5,these_eps_vals,mean_SU_windowed[i],p0=p0,
#      24                                                       sigma=std_error_SU_windowed[i],absolute_sigma=True,bounds=bound)
#
# NameError: name 'std_error_SO_windowed' is not defined

# %%
# Now SU(3)
fig,ax = plt.subplots(1,2,figsize=(16,6))
colors = sb.color_palette('colorblind',4)

###AX0
eps_mid=np.median(eps_windowed,axis=-1)
coeff = 1

y=np.array(SO_fits)[:,coeff]
ci = np.sqrt(np.array(SO_covs)[:,coeff,coeff])
ax[0].semilogx(eps_mid, y*np.power(eps_mid,0),label=r'SO(8)',color='black')
ax[0].fill_between(eps_mid, (y-ci)*np.power(eps_mid,0), (y+ci)*np.power(eps_mid,0), color='black', alpha=.1)

y=np.array(SU_fits)[:,coeff]
ci = np.sqrt(np.array(SU_covs)[:,coeff,coeff])
ax[0].semilogx(eps_mid, y*np.power(eps_mid,0),label=r'SU(3)',color='red')
ax[0].fill_between(eps_mid, (y-ci)*np.power(eps_mid,0), (y+ci)*np.power(eps_mid,0), color='red', alpha=.1)



#print(y)
y=np.array(SU_network_fits)[:,coeff]
ci = 0.5*np.sqrt(np.array(SU_network_covs)[:,coeff,coeff])
ax[0].semilogx(eps_mid, y*np.power(eps_mid,0),label=r'SU(3$)_{nn}$',color='purple')
ax[0].fill_between(eps_mid, (y-ci)*np.power(eps_mid,0), (y+ci)*np.power(eps_mid,0), color='indigo', alpha=.2)

y=np.array(SO_network_fits)[:,coeff]
ci = 0.5*np.sqrt(np.array(SO_network_covs)[:,coeff,coeff])
ax[0].semilogx(eps_mid, y*np.power(eps_mid,0),label=r'SO(8$)_{nn}$',color='blue')
ax[0].fill_between(eps_mid, (y-ci)*np.power(eps_mid,0), (y+ci)*np.power(eps_mid,0), color='blue', alpha=.1)



ax[0].set_xlabel('$\epsilon$')
ax[0].set_ylabel('$a_{}$'.format(coeff))
ax[0].set_ylim(-0.5,0.5)
ax[0].set_xlim(0.01,0.6)
ax[0].legend()

#AX1
confidence_inteval = 96

data = pd.DataFrame({'epsilon':eps,'SOdiff':np.abs(SO_Vdiff),'SUdiff':np.abs(SU_Vdiff),'SUdiff_nn':np.abs(delta_V_nn),'SOdiff_nn':np.abs(delta_V_nn_SO)})
sb.lineplot(ax = ax[1],data=data,x='epsilon',y='SOdiff',label='SO({:})'.format(N*N-1),ci = confidence_inteval,color = 'black' )
sb.lineplot(ax = ax[1],data=data,x='epsilon',y='SUdiff',label='SU({:})'.format(N),ci=confidence_inteval, color = 'Red')
sb.lineplot(ax = ax[1],data=data,x='epsilon',y='SUdiff_nn',label='SU({}'.format(N)+'$)_{nn}$',ci=confidence_inteval, color = 'Purple')
sb.lineplot(ax = ax[1],data=data,x='epsilon',y='SOdiff_nn',label='SO({}'.format(N*N-1)+'$)_{nn}$',ci=confidence_inteval, color = 'Blue')

x = np.logspace(-3,1,100)


ax[1].plot(x,x*0.4,color="Black",linestyle='--')
ax[1].grid(False)
ax[1].plot(x,(x**2)*0.7,color="Red",linestyle='--',linewidth = 1)
ax[1].set_xlabel(r'$\epsilon$')
ax[1].set_ylabel(r'$\Delta V$')
ax[1].set_xscale('log')
ax[1].set_yscale('log')
ax[1].grid(False)
ax[1].legend()
ax[1].set_ylim(1e-3,10)
ax[1].set_xlim(1e-3,10)


fig.savefig('/home/sean/Documents/Work/Level 4/Level-4-Masters-Project/Figures/sliding_window_a_{}_{}_both_sl_dv.png'.format(coeff,time),dpi = 300)

# %%
# Now SU(3)
fig,ax = plt.subplots(1,1,figsize=(10,8))
colors = sb.color_palette('colorblind',4)

###AX0
eps_mid=np.median(eps_windowed,axis=-1)
coeff = 1

y=np.array(SO_fits)[:,coeff]
ci = np.sqrt(np.array(SO_covs)[:,coeff,coeff])
ax.semilogx(eps_mid, y*np.power(eps_mid,0),label=r'SO(8)',color='black')
ax.fill_between(eps_mid, (y-ci)*np.power(eps_mid,0), (y+ci)*np.power(eps_mid,0), color='black', alpha=.1)

y=np.array(SU_fits)[:,coeff]
ci = np.sqrt(np.array(SU_covs)[:,coeff,coeff])
ax.semilogx(eps_mid, y*np.power(eps_mid,0),label=r'SU(3)',color='red')
ax.fill_between(eps_mid, (y-ci)*np.power(eps_mid,0), (y+ci)*np.power(eps_mid,0), color='red', alpha=.1)



#print(y)
y=np.array(SU_network_fits)[:,coeff]
ci = 0.5*np.sqrt(np.array(SU_network_covs)[:,coeff,coeff])
np.savetxt('./p_testing_ci_su.csv',ci,delimiter=',')
ax.semilogx(eps_mid, y*np.power(eps_mid,0),label=r'SU(3$)_{nn}$',color='purple')
ax.fill_between(eps_mid, (y-ci)*np.power(eps_mid,0), (y+ci)*np.power(eps_mid,0), color='indigo', alpha=.2)

y=np.array(SO_network_fits)[:,coeff]
ci = 0.5*np.sqrt(np.array(SO_network_covs)[:,coeff,coeff])
np.savetxt('./p_testing_ci_so.csv',ci,delimiter=',')
ax.semilogx(eps_mid, y*np.power(eps_mid,0),label=r'SO(8$)_{nn}$',color='blue')
ax.fill_between(eps_mid, (y-ci)*np.power(eps_mid,0), (y+ci)*np.power(eps_mid,0), color='blue', alpha=.1)



ax.set_xlabel('$\epsilon$')
ax.set_ylabel('$a_{}$'.format(coeff))
ax.set_ylim(-0.5,0.5)
ax.set_xlim(0.01,0.6)
ax.legend()




fig.savefig('/home/sean/Documents/Work/Level 4/Level-4-Masters-Project/Figures/sliding_window_a_{}_{}.png'.format(coeff,time),dpi = 300)

# %%
ci[np.argmax(SO_network_fits[:250,1])]
# Out:
# 0.08587043704175953
