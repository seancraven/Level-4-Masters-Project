# %%
import sys
sys.path.append('/home/sean/Documents/Work/Level 4/Level-4-Masters-Project')
import numpy as np
import pandas as pd
import random
import datetime
# Setup plotting with matplotlib
import seaborn as sb
import matplotlib
import matplotlib.pyplot as plt
## setup latex plotting
#plt.rc('text', usetex=True)
plt.rc('font', family='serif')
## make font size bigger
matplotlib.rcParams.update({'font.size': 16})
## but make legend smaller
matplotlib.rcParams.update({'legend.fontsize': 14})
## change line thickness
matplotlib.rcParams.update({'lines.linewidth' : 1.75})

import Hyperparam_Testing.Testing_Notebooks.chirallag as cL
import Hyperparam_Testing.Testing_Notebooks.Common_Functions as cf
from tensorflow import keras
from tensorflow.keras import layers 
from tensorflow.keras import models 
import scipy.stats as stats
from numpy.lib.stride_tricks import sliding_window_view
from scipy.optimize import curve_fit as fit

# %%
N=3
gens = cL.gen_gellman(3)
F0 = 1



def matprint(mat, fmt="g"):
    col_maxes = [max([len(("{:"+fmt+"}").format(x)) for x in col]) for col in mat.T]
    for x in mat:
        for i, y in enumerate(x):
            print(("{:"+str(col_maxes[i])+fmt+"}").format(y), end="  ")
        print("")
        
liststrucSU3 = np.array([[1,2,3,1],[1,4,7,.5],[1,5,6,-.5],[2,4,6,.5],[2,5,7,.5],[3,4,5,.5],[3,6,7,-.5],[4,5,8,3**0.5/2],[6,7,8,3**0.5/2]])
liststrucSU2 = np.array([[1,2,3,1],[3,2,1,1]])

def adjointSUN(dim,liststruc):
    dimSUN=dim**2-1
#     admat = np.zeros((8,8,8))
    admat = np.zeros((dimSUN,dimSUN,dimSUN))
    for i in range(liststruc.shape[0]):
        strucc = liststruc[i]
        strucc1 = int(strucc[0])-1
        strucc2 = int(strucc[1])-1
        strucc3 = int(strucc[2])-1
        admat[strucc1,strucc2,strucc3]=strucc[3]
        admat[strucc1,strucc3,strucc2]=-strucc[3]
        admat[strucc3,strucc1,strucc2]=strucc[3]
        admat[strucc3,strucc2,strucc1]=-strucc[3]
        admat[strucc2,strucc3,strucc1]=strucc[3]
        admat[strucc2,strucc1,strucc3]=-strucc[3]
    return admat

adjointSU3 = adjointSUN(3,liststrucSU3)

# %%
# To do, make these work when not supplying stacks of epsilon and transformations.

def get_SO_trans(eps,N):
    ''' Produces 'infinitesimal' transformation matrices for SO(N) given epsilon.
        Epsilon is size of transformation and should be a numpy array of dimension 1.
        N must be larger than 1.
    '''
    
    trans_number = len(eps) 
    # Generate rotation matrices
    SO_samp = np.zeros((trans_number,N,N))

    # Set random off diagonal element of each matrix to one (surely must be a better way to do this)
    poss_inds = range(N)
    SO_inds = [random.sample(poss_inds,2) for i in range(trans_number)]
    SO_indsflat = [i*(N)**2+x*(N)+y for i,(x,y) in enumerate(SO_inds)]
    SO_samp.flat[SO_indsflat] += 1

    # Is this transpose faster than repeating assignment above?
    SO_samp = SO_samp - np.transpose(SO_samp,axes=[0,2,1])
    SO_trans = np.identity(N) + eps[:,None,None]*SO_samp
    # Normalise so that det = 1
    #norm = np.power(np.linalg.det(SO_trans),-1/(N))
    #SO_trans = norm[:,None,None]*SO_trans
    return SO_trans
  
def get_SU_trans(eps,N,liststruct):
    ''' Produces 'infinitesimal' transformation matrices for SO(N) given epsilon.
        Epsilon is size of transformation and should be a numpy array of dimension 1.
        N must be larger than 1.
        Calls adjointSUN which requires liststruct
    '''
    adjointSU = adjointSUN(N,liststruct)
    
    genno=np.random.randint(0,N*N-2,number_predictions)
    SU_trans = np.identity(N*N-1)+eps[:,None,None]*adjointSU[genno]
    # Normalise so that det = 1
    #norm = np.power(np.linalg.det(SU_trans),-1/(N*N-1))
    #SU_trans = norm[:,None,None]*SU_trans
    return SU_trans
    
def apply_trans(trans,vec):
    ''' Apply transformation trans to vector. Assumes both trans and vec are stacks.'''
    trans_vec=np.matmul(trans,vec[:,:,None]).squeeze()
    return trans_vec

# %%
# Compare Transformations
epsmax = 100
epsmin = 0.001
eps_intervals=200
number_predictions=100000


pi=np.random.rand(number_predictions,N*N-1)
dpi=np.random.rand(number_predictions,N*N-1)

# Get epsilons, create copies
eps_vals=np.logspace(np.log10(epsmin),np.log10(epsmax),num=eps_intervals)
eps = np.zeros(number_predictions)
for i,val in enumerate(eps_vals): 
    eps[i*int(number_predictions/eps_intervals):(i+1)*int(number_predictions/eps_intervals)] = val
# Set leftovers to max value
eps[(i+1)*int(number_predictions/eps_intervals):]=val

# SO(N) transformations
SO_trans = get_SO_trans(eps,N*N-1)

SO_pi = apply_trans(SO_trans,pi)
SO_dpi = apply_trans(SO_trans,dpi)

# SU(N) transformations

SU_trans = get_SU_trans(eps,N,liststrucSU3)

SU_pi = apply_trans(SU_trans,pi)
SU_dpi = apply_trans(SU_trans,dpi)


# Get potential values, only care about real part (non zero imag should just be numerical precision errors)

orig_V = cL.get_V(pi,dpi,gens,F0).real
SO_V = cL.get_V(SO_pi,SO_dpi,gens,F0).real
SU_V = cL.get_V(SU_pi,SU_dpi,gens,F0).real

SO_Vdiff = (SO_V - orig_V)/orig_V
SU_Vdiff = (SU_V - orig_V)/orig_V

rand_means = np.mean(np.hstack([np.abs(pi) , np.abs(dpi)]),axis=-1)

# %%
print("Average error of SU(3) transformation: ",np.mean(np.abs(SU_Vdiff)),
      ", and of rotation: ",np.mean(np.abs(SO_Vdiff)))

print("Average potential value: ",np.mean(np.abs(orig_V)),", average pion value:",np.mean(rand_means))
# Out:
# Average error of SU(3) transformation:  383403.7862283498 , and of rotation:  109240.72848341652
# Average potential value:  0.19410528866148827 , average pion value: 0.4995890744351079

# %%
# Standard error by hand to compare with seaborn lineplot

fig,ax = plt.subplots(1,figsize=(9,6))

# Evaluate std deviation is epsilon is created using interval
SO_Vdiff_eps = [np.abs(SO_Vdiff[np.where(eps==val)]) for val in eps_vals]
mean_SO = np.mean(SO_Vdiff_eps,axis=-1)
std_dev_SO = np.std(SO_Vdiff_eps,axis=-1)
std_error_SO = std_dev_SO/np.sqrt([len(s) for s in SO_Vdiff_eps])
SU_Vdiff_eps = [np.abs(SU_Vdiff[np.where(eps==val)]) for val in eps_vals]
mean_SU = np.mean(SU_Vdiff_eps,axis=-1)
std_dev_SU = np.std(SU_Vdiff_eps,axis=-1)
std_error_SU = std_dev_SU/np.sqrt([len(s) for s in SU_Vdiff_eps])
#print(std_dev_SU)

#print(std_error_SU)
ax.plot(eps_vals,mean_SO,marker='.',label='SO({:})'.format(N*N-1))
ax.plot(eps_vals,mean_SU,marker='.',label='SU({:})'.format(N))
Range = 1
ax.fill_between(eps_vals,mean_SO-Range*std_error_SO, mean_SO+Range*std_error_SO,color='blue',alpha=0.5)
ax.fill_between(eps_vals,mean_SU-Range*std_error_SU, mean_SU+Range*std_error_SU,color='orange',alpha=0.5)

ax.set_xlabel(r'$\epsilon$')
ax.set_ylabel(r'$\Delta V$')
ax.set_xscale('log')
ax.set_yscale('log')
ax.legend()
ax.set_ylim(1e-7,1)
ax.set_xlim(1e-3,1)

#fig.tight_layout()
#fig.savefig('DeltaV.png',dpi=200)
# Out:
# (0.001, 1)

# %%
###Find offsets so fit lines line up
so_grad, so_intercept,_,_,_ = stats.linregress(eps_vals,abs(mean_SO))
su_intercept = 10**stats.linregress(np.log10(eps_vals),np.log10(abs(mean_SU)))[0]

# %%
fig,ax = plt.subplots(1,figsize=(9,6))


data = pd.DataFrame({'epsilon':eps,'SOdiff':np.abs(SO_Vdiff),'SUdiff':np.abs(SU_Vdiff)})
sb.lineplot(data=data,x='epsilon',y='SOdiff',label='SO({:})'.format(N*N-1),ci=99,color = 'black' )
sb.lineplot(data=data,x='epsilon',y='SUdiff',label='SU({:})'.format(N),ci=99, color = 'Red')



x = np.logspace(-3,1,100)
y1 = np.exp(x)-(1+x)
y = 1/(1-x)-(1)
#ax.plot(x,y,color="green")
ax.plot(x,x,color="Black",linestyle='--')
ax.grid(False)
#ax.plot(x,y1,color="orange")
ax.plot(x,(x**2),color="Red",linestyle='--',linewidth = 1)


ax.set_xlabel(r'$\epsilon$')
ax.set_ylabel(r'$\Delta V$')
ax.set_xscale('log')
ax.set_yscale('log')
ax.grid(False)
ax.legend()
ax.set_ylim(1e-7,10)
ax.set_xlim(1e-3,10)
fig.tight_layout()
fig.savefig('DeltaV.jpeg',dpi=200,transparent=False)

# %%
data.to_csv('../Training_Data/symetric_training_data_epsilon_and_vdiff.csv')

# %%
[[train_x,train_y],[val_x,val_y]]= cf.gen_and_load(10**5,10**3)

# %%
inital_model = models.Sequential()
inital_model.add(layers.Input(train_x.shape[1]))
inital_model.add(layers.Dense(60,activation='relu'))
inital_model.add(layers.Dense(60,activation='relu'))
inital_model.add(layers.Dense(1))
inital_model.compile(optimizer = 'Adam',loss = 'mape', metrics = [['mean_absolute_error'],['mean_absolute_percentage_error']])
inital_model.summary()

epochs = 50
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense (Dense)                (None, 60)                1020
# _________________________________________________________________
# dense_1 (Dense)              (None, 60)                3660
# _________________________________________________________________
# dense_2 (Dense)              (None, 1)                 61
# =================================================================
# Total params: 4,741
# Trainable params: 4,741
# Non-trainable params: 0
# _________________________________________________________________
# 2022-02-14 09:37:13.669782: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-02-14 09:37:13.767084: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-02-14 09:37:13.767446: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-02-14 09:37:13.768120: I tensorflow/core/platform/cpu_feature_guard.cc:142] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2022-02-14 09:37:13.769676: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-02-14 09:37:13.769949: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-02-14 09:37:13.770190: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-02-14 09:37:14.568977: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-02-14 09:37:14.569253: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-02-14 09:37:14.569455: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-02-14 09:37:14.569656: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1510] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 2820 MB memory:  -> device: 0, name: NVIDIA GeForce GTX 970, pci bus id: 0000:2b:00.0, compute capability: 5.2

# %%
history = inital_model.fit(train_x,train_y,validation_data = (val_x,val_y),batch_size= 256, epochs =epochs)
# Out:
# 2022-02-14 09:37:14.695174: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:185] None of the MLIR Optimization Passes are enabled (registered 2)
# Epoch 1/50
# 387/387 [==============================] - 2s 1ms/step - loss: 49.4831 - mean_absolute_error: 0.0664 - mean_absolute_percentage_error: 49.4831 - val_loss: 32.1440 - val_mean_absolute_error: 0.0439 - val_mean_absolute_percentage_error: 32.1440
# Epoch 2/50
# 387/387 [==============================] - 0s 1ms/step - loss: 25.5058 - mean_absolute_error: 0.0332 - mean_absolute_percentage_error: 25.5058 - val_loss: 20.4541 - val_mean_absolute_error: 0.0264 - val_mean_absolute_percentage_error: 20.4541
# Epoch 3/50
# 387/387 [==============================] - 0s 1ms/step - loss: 20.1473 - mean_absolute_error: 0.0251 - mean_absolute_percentage_error: 20.1473 - val_loss: 19.8848 - val_mean_absolute_error: 0.0235 - val_mean_absolute_percentage_error: 19.8848
# Epoch 4/50
# 387/387 [==============================] - 0s 1ms/step - loss: 17.2646 - mean_absolute_error: 0.0216 - mean_absolute_percentage_error: 17.2646 - val_loss: 16.6824 - val_mean_absolute_error: 0.0204 - val_mean_absolute_percentage_error: 16.6824
# Epoch 5/50
# 387/387 [==============================] - 0s 1ms/step - loss: 16.2452 - mean_absolute_error: 0.0200 - mean_absolute_percentage_error: 16.2452 - val_loss: 16.4149 - val_mean_absolute_error: 0.0187 - val_mean_absolute_percentage_error: 16.4149
# Epoch 6/50
# 387/387 [==============================] - 0s 1ms/step - loss: 15.5838 - mean_absolute_error: 0.0189 - mean_absolute_percentage_error: 15.5838 - val_loss: 14.9809 - val_mean_absolute_error: 0.0185 - val_mean_absolute_percentage_error: 14.9809
# Epoch 7/50
# 387/387 [==============================] - 0s 1ms/step - loss: 14.8717 - mean_absolute_error: 0.0181 - mean_absolute_percentage_error: 14.8717 - val_loss: 15.7729 - val_mean_absolute_error: 0.0178 - val_mean_absolute_percentage_error: 15.7729
# Epoch 8/50
# 387/387 [==============================] - 0s 983us/step - loss: 14.4732 - mean_absolute_error: 0.0175 - mean_absolute_percentage_error: 14.4732 - val_loss: 14.9488 - val_mean_absolute_error: 0.0180 - val_mean_absolute_percentage_error: 14.9488
# Epoch 9/50
# 387/387 [==============================] - 0s 958us/step - loss: 13.5396 - mean_absolute_error: 0.0166 - mean_absolute_percentage_error: 13.5396 - val_loss: 13.0538 - val_mean_absolute_error: 0.0159 - val_mean_absolute_percentage_error: 13.0538
# Epoch 10/50
# 387/387 [==============================] - 0s 972us/step - loss: 13.6390 - mean_absolute_error: 0.0166 - mean_absolute_percentage_error: 13.6390 - val_loss: 12.6375 - val_mean_absolute_error: 0.0159 - val_mean_absolute_percentage_error: 12.6375
# Epoch 11/50
# 387/387 [==============================] - 0s 955us/step - loss: 13.0273 - mean_absolute_error: 0.0160 - mean_absolute_percentage_error: 13.0273 - val_loss: 14.7770 - val_mean_absolute_error: 0.0161 - val_mean_absolute_percentage_error: 14.7770
# Epoch 12/50
# 387/387 [==============================] - 0s 891us/step - loss: 12.5626 - mean_absolute_error: 0.0155 - mean_absolute_percentage_error: 12.5626 - val_loss: 16.6811 - val_mean_absolute_error: 0.0171 - val_mean_absolute_percentage_error: 16.6811
# Epoch 13/50
# 387/387 [==============================] - 0s 940us/step - loss: 12.5618 - mean_absolute_error: 0.0154 - mean_absolute_percentage_error: 12.5618 - val_loss: 11.7470 - val_mean_absolute_error: 0.0152 - val_mean_absolute_percentage_error: 11.7470
# Epoch 14/50
# 387/387 [==============================] - 0s 1ms/step - loss: 12.0988 - mean_absolute_error: 0.0148 - mean_absolute_percentage_error: 12.0988 - val_loss: 11.1853 - val_mean_absolute_error: 0.0147 - val_mean_absolute_percentage_error: 11.1853
# Epoch 15/50
# 387/387 [==============================] - 0s 885us/step - loss: 11.9496 - mean_absolute_error: 0.0147 - mean_absolute_percentage_error: 11.9496 - val_loss: 14.0506 - val_mean_absolute_error: 0.0174 - val_mean_absolute_percentage_error: 14.0506
# Epoch 16/50
# 387/387 [==============================] - 0s 901us/step - loss: 12.0568 - mean_absolute_error: 0.0147 - mean_absolute_percentage_error: 12.0568 - val_loss: 11.5837 - val_mean_absolute_error: 0.0155 - val_mean_absolute_percentage_error: 11.5837
# Epoch 17/50
# 387/387 [==============================] - 0s 961us/step - loss: 11.6171 - mean_absolute_error: 0.0144 - mean_absolute_percentage_error: 11.6171 - val_loss: 11.1801 - val_mean_absolute_error: 0.0144 - val_mean_absolute_percentage_error: 11.1801
# Epoch 18/50
# 387/387 [==============================] - 0s 970us/step - loss: 11.6795 - mean_absolute_error: 0.0143 - mean_absolute_percentage_error: 11.6795 - val_loss: 12.2047 - val_mean_absolute_error: 0.0165 - val_mean_absolute_percentage_error: 12.2047
# Epoch 19/50
# 387/387 [==============================] - 0s 967us/step - loss: 11.5468 - mean_absolute_error: 0.0141 - mean_absolute_percentage_error: 11.5468 - val_loss: 11.0795 - val_mean_absolute_error: 0.0138 - val_mean_absolute_percentage_error: 11.0795
# Epoch 20/50
# 387/387 [==============================] - 0s 954us/step - loss: 11.4142 - mean_absolute_error: 0.0139 - mean_absolute_percentage_error: 11.4142 - val_loss: 12.5088 - val_mean_absolute_error: 0.0145 - val_mean_absolute_percentage_error: 12.5088
# Epoch 21/50
# 387/387 [==============================] - 0s 960us/step - loss: 11.1979 - mean_absolute_error: 0.0137 - mean_absolute_percentage_error: 11.1979 - val_loss: 12.7317 - val_mean_absolute_error: 0.0139 - val_mean_absolute_percentage_error: 12.7317
# Epoch 22/50
# 387/387 [==============================] - 0s 960us/step - loss: 11.2064 - mean_absolute_error: 0.0137 - mean_absolute_percentage_error: 11.2064 - val_loss: 11.1239 - val_mean_absolute_error: 0.0136 - val_mean_absolute_percentage_error: 11.1239
# Epoch 23/50
# 387/387 [==============================] - 0s 1ms/step - loss: 10.9327 - mean_absolute_error: 0.0134 - mean_absolute_percentage_error: 10.9327 - val_loss: 13.7883 - val_mean_absolute_error: 0.0141 - val_mean_absolute_percentage_error: 13.7883
# Epoch 24/50
# 387/387 [==============================] - 0s 920us/step - loss: 11.0283 - mean_absolute_error: 0.0135 - mean_absolute_percentage_error: 11.0283 - val_loss: 11.6687 - val_mean_absolute_error: 0.0144 - val_mean_absolute_percentage_error: 11.6687
# Epoch 25/50
# 387/387 [==============================] - 0s 941us/step - loss: 10.9303 - mean_absolute_error: 0.0133 - mean_absolute_percentage_error: 10.9303 - val_loss: 10.9688 - val_mean_absolute_error: 0.0140 - val_mean_absolute_percentage_error: 10.9688
# Epoch 26/50
# 387/387 [==============================] - 0s 1ms/step - loss: 10.8243 - mean_absolute_error: 0.0132 - mean_absolute_percentage_error: 10.8243 - val_loss: 11.2938 - val_mean_absolute_error: 0.0133 - val_mean_absolute_percentage_error: 11.2938
# Epoch 27/50
# 387/387 [==============================] - 0s 1ms/step - loss: 10.3830 - mean_absolute_error: 0.0128 - mean_absolute_percentage_error: 10.3830 - val_loss: 10.6953 - val_mean_absolute_error: 0.0137 - val_mean_absolute_percentage_error: 10.6953
# Epoch 28/50
# 387/387 [==============================] - 0s 1ms/step - loss: 10.7350 - mean_absolute_error: 0.0130 - mean_absolute_percentage_error: 10.7350 - val_loss: 11.0091 - val_mean_absolute_error: 0.0139 - val_mean_absolute_percentage_error: 11.0091
# Epoch 29/50
# 387/387 [==============================] - 0s 1ms/step - loss: 10.5271 - mean_absolute_error: 0.0129 - mean_absolute_percentage_error: 10.5271 - val_loss: 12.3850 - val_mean_absolute_error: 0.0139 - val_mean_absolute_percentage_error: 12.3850
# Epoch 30/50
# 387/387 [==============================] - 0s 1ms/step - loss: 10.7650 - mean_absolute_error: 0.0131 - mean_absolute_percentage_error: 10.7650 - val_loss: 10.2204 - val_mean_absolute_error: 0.0130 - val_mean_absolute_percentage_error: 10.2204
# Epoch 31/50
# 387/387 [==============================] - 0s 1ms/step - loss: 10.1357 - mean_absolute_error: 0.0125 - mean_absolute_percentage_error: 10.1357 - val_loss: 11.0066 - val_mean_absolute_error: 0.0134 - val_mean_absolute_percentage_error: 11.0066
# Epoch 32/50
# 387/387 [==============================] - 0s 1ms/step - loss: 10.2018 - mean_absolute_error: 0.0125 - mean_absolute_percentage_error: 10.2018 - val_loss: 10.8369 - val_mean_absolute_error: 0.0141 - val_mean_absolute_percentage_error: 10.8369
# Epoch 33/50
# 387/387 [==============================] - 0s 1ms/step - loss: 10.4645 - mean_absolute_error: 0.0127 - mean_absolute_percentage_error: 10.4645 - val_loss: 9.6586 - val_mean_absolute_error: 0.0121 - val_mean_absolute_percentage_error: 9.6586
# Epoch 34/50
# 387/387 [==============================] - 0s 999us/step - loss: 10.0554 - mean_absolute_error: 0.0123 - mean_absolute_percentage_error: 10.0554 - val_loss: 10.4083 - val_mean_absolute_error: 0.0129 - val_mean_absolute_percentage_error: 10.4083
# Epoch 35/50
# 387/387 [==============================] - 0s 998us/step - loss: 9.9744 - mean_absolute_error: 0.0122 - mean_absolute_percentage_error: 9.9744 - val_loss: 10.6208 - val_mean_absolute_error: 0.0122 - val_mean_absolute_percentage_error: 10.6208
# Epoch 36/50
# 387/387 [==============================] - 0s 1ms/step - loss: 10.2194 - mean_absolute_error: 0.0124 - mean_absolute_percentage_error: 10.2194 - val_loss: 10.2344 - val_mean_absolute_error: 0.0120 - val_mean_absolute_percentage_error: 10.2344
# Epoch 37/50
# 387/387 [==============================] - 0s 959us/step - loss: 9.8165 - mean_absolute_error: 0.0120 - mean_absolute_percentage_error: 9.8165 - val_loss: 9.8316 - val_mean_absolute_error: 0.0123 - val_mean_absolute_percentage_error: 9.8316
# Epoch 38/50
# 387/387 [==============================] - 0s 951us/step - loss: 10.0855 - mean_absolute_error: 0.0122 - mean_absolute_percentage_error: 10.0855 - val_loss: 10.5343 - val_mean_absolute_error: 0.0130 - val_mean_absolute_percentage_error: 10.5343
# Epoch 39/50
# 387/387 [==============================] - 0s 949us/step - loss: 9.7576 - mean_absolute_error: 0.0120 - mean_absolute_percentage_error: 9.7576 - val_loss: 10.3639 - val_mean_absolute_error: 0.0125 - val_mean_absolute_percentage_error: 10.3639
# Epoch 40/50
# 387/387 [==============================] - 0s 937us/step - loss: 9.7886 - mean_absolute_error: 0.0119 - mean_absolute_percentage_error: 9.7886 - val_loss: 9.5606 - val_mean_absolute_error: 0.0117 - val_mean_absolute_percentage_error: 9.5606
# Epoch 41/50
# 387/387 [==============================] - 0s 992us/step - loss: 9.9163 - mean_absolute_error: 0.0120 - mean_absolute_percentage_error: 9.9163 - val_loss: 12.8176 - val_mean_absolute_error: 0.0133 - val_mean_absolute_percentage_error: 12.8176
# Epoch 42/50
# 387/387 [==============================] - 0s 956us/step - loss: 9.6099 - mean_absolute_error: 0.0118 - mean_absolute_percentage_error: 9.6099 - val_loss: 9.7652 - val_mean_absolute_error: 0.0123 - val_mean_absolute_percentage_error: 9.7652
# Epoch 43/50
# 387/387 [==============================] - 0s 944us/step - loss: 9.5337 - mean_absolute_error: 0.0117 - mean_absolute_percentage_error: 9.5337 - val_loss: 9.4243 - val_mean_absolute_error: 0.0115 - val_mean_absolute_percentage_error: 9.4243
# Epoch 44/50
# 387/387 [==============================] - 0s 962us/step - loss: 9.5316 - mean_absolute_error: 0.0116 - mean_absolute_percentage_error: 9.5316 - val_loss: 9.1592 - val_mean_absolute_error: 0.0116 - val_mean_absolute_percentage_error: 9.1592
# Epoch 45/50
# 387/387 [==============================] - 0s 864us/step - loss: 9.3664 - mean_absolute_error: 0.0115 - mean_absolute_percentage_error: 9.3664 - val_loss: 9.6063 - val_mean_absolute_error: 0.0127 - val_mean_absolute_percentage_error: 9.6063
# Epoch 46/50
# 387/387 [==============================] - 0s 934us/step - loss: 9.3357 - mean_absolute_error: 0.0114 - mean_absolute_percentage_error: 9.3357 - val_loss: 9.7038 - val_mean_absolute_error: 0.0124 - val_mean_absolute_percentage_error: 9.7038
# Epoch 47/50
# 387/387 [==============================] - 0s 998us/step - loss: 9.4624 - mean_absolute_error: 0.0115 - mean_absolute_percentage_error: 9.4624 - val_loss: 11.1169 - val_mean_absolute_error: 0.0132 - val_mean_absolute_percentage_error: 11.1169
# Epoch 48/50
# 387/387 [==============================] - 0s 966us/step - loss: 9.1919 - mean_absolute_error: 0.0112 - mean_absolute_percentage_error: 9.1919 - val_loss: 10.4411 - val_mean_absolute_error: 0.0130 - val_mean_absolute_percentage_error: 10.4411
# Epoch 49/50
# 387/387 [==============================] - 0s 966us/step - loss: 9.2770 - mean_absolute_error: 0.0113 - mean_absolute_percentage_error: 9.2770 - val_loss: 9.7555 - val_mean_absolute_error: 0.0115 - val_mean_absolute_percentage_error: 9.7555
# Epoch 50/50
# 387/387 [==============================] - 0s 1ms/step - loss: 9.1342 - mean_absolute_error: 0.0112 - mean_absolute_percentage_error: 9.1342 - val_loss: 10.6901 - val_mean_absolute_error: 0.0136 - val_mean_absolute_percentage_error: 10.6901

# %%
validation_MAPE = history.history['val_mean_absolute_percentage_error']

# %%
test_data= cf.gen_and_load(10**5,0)

# %%
### Generate New test data for nn prediction
pi_dpi,v = test_data[1]
pis =pi_dpi[:,:8]
dpis = pi_dpi[:,8:]

SU_dpi_nn = apply_trans(SU_trans,dpis)
SU_pi_nn = apply_trans(SU_trans,pis)
SU_pi_dpi_nn = np.hstack((SU_pi_nn,SU_dpi_nn))
SU_V_nn_test = cL.get_V(SU_pi_nn,SU_dpi_nn,gens,F0).real
###I only want the transformed data on the interval 0-1

# %%
print('Range of Pi\' fields',np.min(SU_pi_dpi_nn),'to',np.max(SU_pi_dpi_nn))
print('Mean Pi\' Field', np.mean(SU_pi_dpi_nn))
print('Range of Pi fields',np.min(pi_dpi),'to',np.max(pi_dpi))
# Out:
# Range of Pi' fields -134.1505912702257 to 133.84763455517628
# Mean Pi' Field 0.8020282243839241
# Range of Pi fields 0.025675543465155857 to 0.9999999164022045

# %%
fig , ax = plt.subplots(2,8,sharey= True, figsize = (10,8))
plt.subplots_adjust(hspace= 0.4,wspace= 0.5)
for i in range(8):
    ax[0,i].hist(SU_pi_dpi_nn[:,i], density = True, color = 'black') 
    #ax[0,i].set_xticks([0,1])
    #ax[1,i].set_xticks([0,1])
    ax[1,i].hist(SU_pi_dpi_nn[:,8+i],density = True, color = 'black')
    ax[0,i].set_xlabel('$\phi_{{{}}}$'.format(i))
    ax[1,i].set_xlabel('$d\phi_{{{}}}$'.format(i))
fig.supylabel('Frequency Density')
fig_2 = plt.figure(figsize= (10,8))
plt.hist(abs(SU_V_nn_test),density= True, bins = 1000, color = 'black',label=  '$\phi \sim U^{1/4}$')
#plt.hist(df_SU_pi_dpi_nn[:,-1],density= True, bins = 1000, color = 'blue',label=  '$\phi \sim U^{1/4}$' )
plt.xlabel('$V(\phi)$')
plt.ylabel('Frequency Density')
plt.xlim(0,10**5)
plt.legend()

# %%
cf.field_plotter(pi_dpi,v)

# %%
#Use Neural network to predict transformation
#Delta Vnn calculated for plotting 
V_nn = inital_model.predict(SU_pi_dpi_nn)
delta_V_nn = abs((V_nn[:,0]-v)/v)

# %%
fig,ax = plt.subplots(1,figsize=(9,6))


data = pd.DataFrame({'epsilon':eps,'SOdiff':np.abs(SO_Vdiff),'SUdiff':np.abs(SU_Vdiff),'SUdiff_nn':np.abs(delta_V_nn)})
sb.lineplot(data=data,x='epsilon',y='SOdiff',label='SO({:})'.format(N*N-1),ci=95,color = 'black' )
sb.lineplot(data=data,x='epsilon',y='SUdiff',label='SU({:})'.format(N),ci=95, color = 'Red')
sb.lineplot(data=data,x='epsilon',y='SUdiff_nn',label='SU({}'.format(N)+'$)_{nn}$',ci=95, color = 'Purple')


x = np.logspace(-3,1,100)
y1 = np.exp(x)-(1+x)
y = 1/(1-x)-(1)
#ax.plot(x,y,color="green")
ax.plot(x,x*0.4,color="Black",linestyle='--')
ax.grid(False)
#ax.plot(x,y1,color="orange")
ax.plot(x,(x**2)*0.7,color="Red",linestyle='--',linewidth = 1)
ax.plot(x,np.ones_like(x)*validation_MAPE[-2]/100, color = 'purple',linestyle = '--', label = 'Network MAPE')

ax.set_xlabel(r'$\epsilon$')
ax.set_ylabel(r'$\Delta V$')
ax.set_xscale('log')
ax.set_yscale('log')
ax.grid(False)
ax.legend()
ax.set_ylim(1e-3,10)
ax.set_xlim(1e-3,10)
fig.tight_layout()
fig.savefig('DeltaV_inital.jpeg',dpi=200,transparent=False)

# %%
model = keras.models.load_model('/home/sean/Documents/Work/Level 4/Level-4-Masters-Project/Hyperparam_Testing/Testing_Notebooks/Optimised_Network/5_107.0datapoints.h5')

# %%
pred_V = model.predict(pi_dpi)[:,0]
MAPE = np.mean(abs((pred_V - v)/v))
print('MAPE = ',round(MAPE*100,2))
# Out:
# MAPE =  1.24

# %%
V_nn = model.predict(SU_pi_dpi_nn)
print(V_nn)
print(V_nn[:,0].shape)
delta_V_nn = abs((V_nn[:,0]-v)/v)
# Out:
# [[3.8460247e-02]
#  [3.3532760e-01]
#  [4.5547906e-02]
#  ...
#  [1.1483997e+00]
#  [4.9539066e+01]
#  [3.6604831e-04]]
# (100000,)

# %%
confidence_inteval = 96

fig_2,ax = plt.subplots(1,figsize=(9,6))
data = pd.DataFrame({'epsilon':eps,'SOdiff':np.abs(SO_Vdiff),'SUdiff':np.abs(SU_Vdiff),'SUdiff_nn':np.abs(delta_V_nn)})
sb.lineplot(data=data,x='epsilon',y='SOdiff',label='SO({:})'.format(N*N-1),ci = confidence_inteval,color = 'black' )
sb.lineplot(data=data,x='epsilon',y='SUdiff',label='SU({:})'.format(N),ci=confidence_inteval, color = 'Red')
sb.lineplot(data=data,x='epsilon',y='SUdiff_nn',label='SU({}'.format(N)+'$)_{nn}$',ci=confidence_inteval, color = 'Purple')


x = np.logspace(-3,1,100)
y1 = np.exp(x)-(1+x)
y = 1/(1-x)-(1)
#ax.plot(x,y,color="green")
ax.plot(x,x*0.4,color="Black",linestyle='--')
ax.grid(False)
#ax.plot(x,y1,color="orange")
ax.plot(x,(x**2)*0.7,color="Red",linestyle='--',linewidth = 1)
ax.plot(x,np.ones_like(x)*MAPE, color = 'purple',linestyle = '--', label = 'Network MAPE')

ax.set_xlabel(r'$\epsilon$')
ax.set_ylabel(r'$\Delta V$')
ax.set_xscale('log')
ax.set_yscale('log')
ax.grid(False)
ax.legend()
ax.set_ylim(1e-3,10)
ax.set_xlim(1e-3,10)
fig_2.tight_layout()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_11386/1421438904.py in <module>
#      28 fig_2.tight_layout()
#      29
# ---> 30 time = datetime.datetime()
#      31 print(time)
#      32 fig_2.savefig('DeltaV_improved.jpeg',dpi=200,transparent=False)
#
# TypeError: function missing required argument 'year' (pos 1)

# %%
import time 
time = datetime.date.today()

fig_2.savefig('DeltaV_improved_{}.jpeg'.format(time),dpi=200,transparent=False)

# %%
coef_su = np.polyfit(eps_vals, mean_SU,3)
for i,ii in enumerate(coef_su):
    print('a{}'.format(i)+'='+str(ii))
# Out:
# a0=29.170992418018912
# a1=-1597.6074540943441
# a2=24539.517516639655
# a3=-19196.594512374155

# %%
plt.loglog(eps_vals,np.mean([np.abs(delta_V_nn[np.where(eps==val)]) for val in eps_vals],axis = 1))

# %%
fig,ax = plt.subplots(1,figsize=(9,6))

SO_Vdiff_eps = [np.abs(SO_Vdiff[np.where(eps==val)]) for val in eps_vals] ##subsampling only the points which have epsilon values
mean_SO = np.mean(SO_Vdiff_eps,axis=-1)
std_dev_SO = np.std(SO_Vdiff_eps,axis=-1)
std_error_SO = std_dev_SO/np.sqrt([len(s) for s in SO_Vdiff_eps])
SU_Vdiff_eps = [np.abs(SU_Vdiff[np.where(eps==val)]) for val in eps_vals]
mean_SU = np.mean(SU_Vdiff_eps,axis=-1)
std_dev_SU = np.std(SU_Vdiff_eps,axis=-1)
std_error_SU = std_dev_SU/np.sqrt([len(s) for s in SU_Vdiff_eps])
nn_eps = [np.abs(delta_V_nn[np.where(eps==val)]) for val in eps_vals]
mean_nn = np.mean(nn_eps,axis = -1)
std_nn = np.std(nn_eps,axis =-1)
ste_nn = std_nn/np.sqrt([len(s) for s in nn_eps])

ax.plot(eps_vals,mean_SO,marker='',label='SO({:})'.format(N*N-1),c = 'black',linewidth = 0.8)
ax.plot(eps_vals,mean_SU,marker='',label='SU({:})'.format(N),c = 'red',linewidth = 0.8)
ax.plot(eps_vals,mean_nn,marker='',label='SU({:}'.format(N)+'$)_{nn}$', color = 'purple',linewidth = 0.8)
Range = 1
ax.fill_between(eps_vals,mean_SO-Range*std_error_SO, mean_SO+Range*std_error_SO,color='black',linewidth = 0.6,alpha=0.3)
ax.fill_between(eps_vals,mean_SU-Range*std_error_SU, mean_SU+Range*std_error_SU,color='red',linewidth = 0.6,alpha=0.3)
ax.fill_between(eps_vals,mean_nn-Range*ste_nn, mean_nn+Range*ste_nn,color='purple',alpha=0.3,)

ax.set_xlabel(r'$\epsilon$')
ax.set_ylabel(r'$\Delta V$')
ax.set_xscale('log')
ax.set_yscale('log')
ax.legend()
ax.set_ylim(1e-3,10)
ax.set_xlim(1e-3,10)
# Out:
# (0.001, 10)

# %%
fig, ax = plt.subplots()
mean_nn.shape
ax.plot(eps_vals,mean_SO)
ax.set_ylim(1e-3,1)
ax.set_xlim(1e-3,1)
# Out:
# (0.001, 1.0)

# %%
# Create windows
def p5(x,a0,a1,a2,a3,a4,a5):
    return a0+x*a1+a2*x**2+a3*x**3+a4*x**4+a5*x**5

p0 = np.zeros(6)
window = 33
step=1

eps_windowed = sliding_window_view(eps_vals,window)[::step]
mean_SO_windowed = sliding_window_view(mean_SO,window)[::step]
mean_SU_windowed = sliding_window_view(mean_SU,window)[::step]
#mean_arb_windowed = sliding_window_view(mean_arb,window)[::step]

#mean_SO_network_windowed = sliding_window_view(mean_SO_network,window)[::step]
mean_SU_network_windowed = sliding_window_view(mean_nn,window)[::step]
#mean_arb_network_windowed = sliding_window_view(mean_arb_network,window)[::step]


std_error_SO_windowed = sliding_window_view(std_error_SO,window)[::step]
std_error_SU_windowed = sliding_window_view(std_error_SU,window)[::step]
#std_error_arb_windowed = sliding_window_view(std_error_arb,window)[::step]

#std_error_SO_network_windowed = sliding_window_view(std_error_SO_network,window)[::step]
std_error_SU_network_windowed = sliding_window_view(mean_nn,window)[::step]
#td_error_arb_network_windowed = sliding_window_view(std_error_arb_network,window)[::step]

# %%
SO_fits=np.zeros((eps_windowed.shape[0],len(p0)))
SU_fits=np.zeros((eps_windowed.shape[0],len(p0)))
arb_fits=np.zeros((eps_windowed.shape[0],len(p0)))

SO_network_fits=np.zeros((eps_windowed.shape[0],len(p0)))
SU_network_fits=np.zeros((eps_windowed.shape[0],len(p0)))
arb_network_fits=np.zeros((eps_windowed.shape[0],len(p0)))


SO_covs=np.zeros((eps_windowed.shape[0],len(p0),len(p0)))
SU_covs=np.zeros((eps_windowed.shape[0],len(p0),len(p0)))
#arb_covs=np.zeros((eps_windowed.shape[0],len(p0),len(p0)))

#SO_network_covs=np.zeros((eps_windowed.shape[0],len(p0),len(p0)))
SU_network_covs=np.zeros((eps_windowed.shape[0],len(p0),len(p0)))
#arb_network_covs=np.zeros((eps_windowed.shape[0],len(p0),len(p0)))

bound = (-0.01,10)
for i,these_eps_vals in enumerate(eps_windowed):
    #print(i/len(eps_windowed))
    SO_fit_params,SO_fit_cov=fit(p5,these_eps_vals,mean_SO_windowed[i],p0=p0,
                                                      sigma=std_error_SO_windowed[i],absolute_sigma=True,bounds=bound)
    SU_fit_params,SU_fit_cov=fit(p5,these_eps_vals,mean_SU_windowed[i],p0=p0,
                                                      sigma=std_error_SU_windowed[i],absolute_sigma=True,bounds=bound)
    
    
    SU_network_fit_params,SU_network_fit_cov=fit(p5,these_eps_vals,mean_SU_network_windowed[i],
                                                                    p0=p0,sigma=std_error_SU_network_windowed[i],absolute_sigma=True,
                                                                    bounds=bound)
    

    SO_fits[i]=(SO_fit_params)
    SO_covs[i]=(SO_fit_cov)
    SU_fits[i]=(SU_fit_params)
    SU_covs[i]=(SU_fit_cov)
    

    #SO_network_fits[i]=(SO_network_fit_params)
    #SO_network_covs[i]=(SO_network_fit_cov)
    SU_network_fits[i]=(SU_network_fit_params)
    SU_network_covs[i]=(SU_network_fit_cov)
    #arb_network_fits[i]=(arb_network_fit_params)
    #arb_network_covs[i]=(arb_network_fit_cov)

# %%
# Now SU(3)
fig,ax = plt.subplots(1,figsize=(10,6))
colors = sb.color_palette('colorblind',4)
eps_mid=np.median(eps_windowed,axis=-1)

coeff = 1
y=np.array(SU_fits)[:,coeff]
ci = np.sqrt(np.array(SU_covs)[:,coeff,coeff])
ax.semilogx(eps_mid, y*np.power(eps_mid,0),label=r'SU(3)',color='red')
ax.fill_between(eps_mid, (y-ci)*np.power(eps_mid,0), (y+ci)*np.power(eps_mid,0), color='red', alpha=.1)


y=np.array(SO_fits)[:,coeff]
ci = np.sqrt(np.array(SO_covs)[:,coeff,coeff])
ax.semilogx(eps_mid, y*np.power(eps_mid,0),label=r'SO(8)',color='black')
ax.fill_between(eps_mid, (y-ci)*np.power(eps_mid,0), (y+ci)*np.power(eps_mid,0), color='black', alpha=.1)
#print(y)
y=np.array(SU_network_fits)[:,coeff]
ci = 0.01*np.sqrt(np.array(SU_network_covs)[:,coeff,coeff])
ax.semilogx(eps_mid, y*np.power(eps_mid,0),label=r'SU(3$)_{nn}$',color='purple')
ax.fill_between(eps_mid, (y-ci)*np.power(eps_mid,0), (y+ci)*np.power(eps_mid,0), color='purple', alpha=.1)
ax.set_xlabel('$\epsilon$')
ax.set_ylabel('a{}'.format(coeff))
ax.set_ylim(-1,1)
ax.set_xlim(0.01,10)
plt.legend()
fig.savefig('/home/sean/Documents/Work/Level 4/Level-4-Masters-Project/Figures/sliding_window_a_{}_{}.png'.format(coeff,time),dpi = 300)
